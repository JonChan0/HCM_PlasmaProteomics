# %% [markdown]
# # GWAS via REGENIE for PP
#
# This uses dsub (as opposed to WDL + Cromwell) to submit bash scripts corresponding to REGENIE for GWAS.
#
# Template for code: https://workbench.researchallofus.org/workspaces/aou-rw-5981f9dc/aouldlgwasregeniedsubctv6duplicate/analysis/preview/4.0_regenie_dsub_HP_TM.ipynb
# i.e the GWAS for LDL-C done by Bick et al, 2024
#
# Modified for my appplications.

# %%
## Python Package Import
import sys
import os 
import numpy as np
import pandas as pd
from datetime import datetime

##Ensuring dsub is up to date
# !pip3 install --upgrade dsub
# Out:
# Requirement already satisfied: dsub in /home/jupyter/.local/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: funcsigs==1.0.2 in /opt/conda/lib/python3.10/site-packages (from dsub) (1.0.2)
# Requirement already satisfied: google-api-core<=2.19.0,>=2.7.3 in /opt/conda/lib/python3.10/site-packages (from dsub) (2.11.1)
# Requirement already satisfied: google-api-python-client<=2.131.0,>=2.47.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (2.131.0)
# Requirement already satisfied: google-auth-httplib2<=0.2.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.2.0)
# Requirement already satisfied: google-auth<=2.29.0,>=2.6.6 in /opt/conda/lib/python3.10/site-packages (from dsub) (2.22.0)
# Requirement already satisfied: google-cloud-batch<=0.17.20 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.17.20)
# Requirement already satisfied: httplib2<=0.22.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.21.0)
# Requirement already satisfied: mock<=5.1.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (5.1.0)
# Requirement already satisfied: parameterized<=0.9.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.9.0)
# Requirement already satisfied: protobuf<=5.26.0,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (3.19.6)
# Requirement already satisfied: pyasn1-modules<=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.2.7)
# Requirement already satisfied: pyasn1<=0.6.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.4.8)
# Requirement already satisfied: python-dateutil<=2.9.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (2.8.2)
# Requirement already satisfied: pytz<=2024.1 in /opt/conda/lib/python3.10/site-packages (from dsub) (2023.3)
# Requirement already satisfied: pyyaml<=6.0.1 in /opt/conda/lib/python3.10/site-packages (from dsub) (6.0.1)
# Requirement already satisfied: rsa<=4.9 in /opt/conda/lib/python3.10/site-packages (from dsub) (4.9)
# Requirement already satisfied: tabulate<=0.9.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.9.0)
# Requirement already satisfied: tenacity<=8.2.3 in /opt/conda/lib/python3.10/site-packages (from dsub) (8.2.3)
# Requirement already satisfied: uritemplate<=4.1.1 in /opt/conda/lib/python3.10/site-packages (from dsub) (3.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core<=2.19.0,>=2.7.3->dsub) (1.60.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /opt/conda/lib/python3.10/site-packages (from google-api-core<=2.19.0,>=2.7.3->dsub) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<=2.29.0,>=2.6.6->dsub) (4.2.4)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<=2.29.0,>=2.6.6->dsub) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<=2.29.0,>=2.6.6->dsub) (1.26.15)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-batch<=0.17.20->dsub) (1.22.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.10/site-packages (from httplib2<=0.22.0->dsub) (3.0.9)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-batch<=0.17.20->dsub) (1.48.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-batch<=0.17.20->dsub) (1.48.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<=2.19.0,>=2.7.3->dsub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<=2.19.0,>=2.7.3->dsub) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<=2.19.0,>=2.7.3->dsub) (2024.2.2)

# %%
#Defining environment variables
# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env JOB_ID={LINE_COUNT_JOB_ID}
## Defining necessary pathways
my_bucket = os.environ['WORKSPACE_BUCKET']
## Setting for running dsub jobs
pd.set_option('display.max_colwidth', 0)

USER_NAME = os.getenv('OWNER_EMAIL').split('@')[0].replace('.','-')

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env USER_NAME={USER_NAME}
# Out:
# env: JOB_ID={LINE_COUNT_JOB_ID}
# env: USER_NAME=jon126

# %% [markdown]
# ## PLINK QC Step
#
# This runs the code and submits the job for each chromosome to run the preparatory QC step which is phenotype-agnostic.

# %%
## MODIFY FOR FULL DATA RUN 
JOB_NAME='1_regenie_plinkprep'

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env JOB_NAME={JOB_NAME}
# Out:
# env: JOB_NAME=1_regenie_plinkprep

# %%
## Analysis Results Folder 
line_count_results_folder = os.path.join(
    os.getenv('WORKSPACE_BUCKET'),
    'dsub',
    'results',
    JOB_NAME,
    USER_NAME,
    datetime.now().strftime('%Y%m%d'))

line_count_results_folder
# Out:
# 'gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241001'

# %%
## Where the output files will go
output_files = os.path.join(line_count_results_folder, "results")
print(output_files)

OUTPUT_FILES = output_files

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env OUTPUT_FILES={OUTPUT_FILES}
# Out:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241001/results
# env: OUTPUT_FILES=gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241001/results

# %%
#This is the plink preparatory in REGENIE 
filename='1_regenie_plinkprep.sh'

script = '''

set -o pipefail 
set -o errexit

plink \
    --bed "${bedfile}" \
    --bim "${bimfile}" \
    --fam "${famfile}" \
    --threads 3 \ 
    --geno 0.01 \
    --hwe 1e-15 \
    --indep-pairwise 1000 100 0.8 \
    --write-snplist \
    --out qc_ldpruned_snps_chr"${chr}"

export output_snplist="qc_ldpruned_snps_chr${chr}.snplist" 
export output_ldprune_in="qc_ldpruned_snps_chr${chr}.prune.in" 
export output_ldprune_out="qc_ldpruned_snps_chr${chr}.prune.out"

mv ${output_snplist} ${output_ldprune_in} ${output_ldprune_out} -t ${OUTPUT_PATH}
'''

with open(filename,'w') as fp:
    fp.write(script)

# %%
# !gsutil cp ./1_regenie_plinkprep.sh {my_bucket}/dsub/scripts/
# Out:
# Copying file://./1_regenie_plinkprep.sh [Content-Type=text/x-sh]...
# / [1 files][  527.0 B/  527.0 B]
# Operation completed over 1 objects/527.0 B.

# %%
#Check the file is there
# !gsutil ls {my_bucket}/dsub/scripts/*.sh
# Out:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/1_regenie_plinkprep.sh
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/2_regenie_aous_pp.sh

# %%
# !gsutil -u $GOOGLE_PROJECT ls -lh gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/
# Out:
# 423.72 GiB  2023-09-26T17:40:39Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr1.bed
# 356.34 MiB  2023-09-26T13:42:19Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr1.bim
#   4.45 MiB  2023-09-26T13:41:54Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr1.fam
# 272.02 GiB  2023-09-26T16:05:59Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr10.bed
# 238.88 MiB  2023-09-26T13:42:14Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr10.bim
#   4.45 MiB  2023-09-26T13:41:52Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr10.fam
# 253.58 GiB  2023-09-26T15:59:01Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr11.bed
# 217.12 MiB  2023-09-26T13:42:15Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr11.bim
#   4.45 MiB  2023-09-26T13:42:06Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr11.fam
# 256.77 GiB  2023-09-26T15:57:06Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr12.bed
# 223.32 MiB  2023-09-26T13:42:19Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr12.bim
#   4.45 MiB  2023-09-26T13:41:52Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr12.fam
# 183.37 GiB  2023-09-26T15:19:14Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr13.bed
# 159.52 MiB  2023-09-26T13:42:19Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr13.bim
#   4.45 MiB  2023-09-26T13:41:56Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr13.fam
#  170.6 GiB  2023-09-26T15:10:23Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr14.bed
# 145.93 MiB  2023-09-26T13:42:17Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr14.bim
#   4.45 MiB  2023-09-26T13:42:08Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr14.fam
# 164.79 GiB  2023-09-26T15:09:08Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr15.bed
# 141.54 MiB  2023-09-26T13:42:10Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr15.bim
#   4.45 MiB  2023-09-26T13:41:56Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr15.fam
# 189.84 GiB  2023-09-26T15:20:16Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr16.bed
# 164.26 MiB  2023-09-26T13:42:13Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr16.bim
#   4.45 MiB  2023-09-26T13:41:55Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr16.fam
# 175.42 GiB  2023-09-26T15:12:08Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr17.bed
#  155.4 MiB  2023-09-26T13:42:19Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr17.bim
#   4.45 MiB  2023-09-26T13:41:55Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr17.fam
# 146.33 GiB  2023-09-26T15:01:04Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr18.bed
# 125.75 MiB  2023-09-26T13:42:17Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr18.bim
#   4.45 MiB  2023-09-26T13:41:54Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr18
s://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/1_regenie_plinkprep.sh" #From above command
#
# # Python is 'right side limited' wherein the last value is not included
# # To run the regression across all chromosomes, set lower to 1 and upper to 23
# # To run across one chromosome, set lower to the chomosome-of-interest and upper to the following
#
# # LOWER=1
# # UPPER=23
#
# #Test on 1 chromosome first
# LOWER=15
# UPPER=16
# for ((chromo=$LOWER;chromo<$UPPER;chromo+=1))
# do
#     dsub \
#     --provider google-cls-v2 \
#     --user-project "${GOOGLE_PROJECT}" \
#     --project "${GOOGLE_PROJECT}" \
#     --image "us.gcr.io/broad-dsp-gcr-public/terra-jupyter-aou:2.2.14" \
#     --network "${AOU_NETWORK}" \
#     --subnetwork "${AOU_SUBNETWORK}" \
#     --service-account "$(gcloud config get-value account)" \
#     --user "${DSUB_USER_NAME}" \
#     --regions us-central1 \
#     --logging "${WORKSPACE_BUCKET}/dsub/logs/{job-name}/{user-id}/$(date +'%Y%m%d/%H%M%S')/{job-id}-{task-id}-{task-attempt}.log" \
#     "$@" \
#     --preemptible \
#     --disk-size 1000 \
#     --boot-disk-size 500 \
#     --machine-type ${MACHINE_TYPE} \
#     --name "${JOB_NAME}" \
#     --script "${BASH_SCRIPT}" \
#     --env GOOGLE_PROJECT=${GOOGLE_PROJECT} \
#     --input bedfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.bed" \
#     --input bimfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.bim" \
#     --input famfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.fam" \
#     --env chr=${chromo} \
#     --output-recursive OUTPUT_PATH="${OUTPUT_FILES}/${chromo}"
# done
# Out:
# Job properties:
#   job-id: 1-regenie---jon126--241001-113153-36
#   job-name: 1-regenie-plinkprep
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/1771003859732048182
# Launched job-id: 1-regenie---jon126--241001-113153-36
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs '1-regenie---jon126--241001-113153-36' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs '1-regenie---jon126--241001-113153-36' --users 'jon126'

# %%
# Check the status of your job submissions

# !dstat \
    --provider google-cls-v2 \
    --project terra-vpc-sc-4e1b6fe8 \
    --location us-central1 \
    --jobs '*' \
    --users 'jon126' \
    --status '*'
# Out:
# Job Name         Status                                      Last Update
# ---------------  ------------------------------------------  --------------
# 1-regenie-pl...  Started running "user-command"              10-01 12:29:26
# 1-regenie-pl...  Stopped running "user-command": exit st...  09-30 18:31:52
# 1-regenie-pl...  Stopped running "user-command": exit st...  09-30 19:05:05
# 1-regenie-pl...  worker was terminated                       09-30 16:41:42
# 1-regenie-pl...  Stopped running "user-command": exit st...  09-30 20:37:09
# 1-regenie-pl...  Stopped running "user-command": exit st...  09-30 21:11:09
# 1-regenie-pl...  worker was terminated                       09-30 20:35:34
# 1-regenie-pl...  worker was terminated                       09-30 17:24:32
# 1-regenie-pl...  Stopped running "user-command": exit st...  09-30 21:35:39
# 1-regenie-pl...  Stopped running "user-command": exit st...  09-30 23:08:16
# 1-regenie-pl...  Stopped running "user-command": exit st...  09-30 23:28:05
# 1-regenie-pl...  Stopped running "user-command": exit st...  10-01 01:31:46
# 1-regenie-pl...  worker was terminated                       09-30 17:19:50
# 1-regenie-pl...  worker was terminated                       10-01 01:43:05
# 1-regenie-pl...  worker was terminated                       10-01 00:02:33
# 1-regenie-pl...  worker was terminated                       10-01 00:02:34
# 1-regenie-pl...  worker was terminated                       09-30 17:26:08
# 1-regenie-pl...  Stopped running "user-command": exit st...  10-01 06:02:44
# 1-regenie-pl...  Stopped running "user-command": exit st...  10-01 05:17:42
# 1-regenie-pl...  worker was terminated                       10-01 00:02:34
# 1-regenie-pl...  worker was terminated                       09-30 15:50:45
# 1-regenie-pl...  worker was terminated                       09-30 17:26:09
# 1-regenie-pl...  Stopped running "user-command": exit st...  10-01 09:28:14
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  Stopped running "localization": exit st...  09-30 14:52:25
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  The operation was cancelled                 09-30 15:09:36
# 1-regenie-pl...  Stopped running "user-command": exit st...  09-30 12:24:20
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:34
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 12:25:33
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:09
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:09
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:09
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:09
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:10
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:10
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:41:11
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...  The operation was cancelled                 09-30 11:33:46
# 1-regenie-pl...
ile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr1.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr1.bim
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr1.fam
#   internal-id: projects/282373700333/locations/us-central1/operations/2520027973218601661
#   job-id: regenie-nt--jon126--240927-123947-19
#   job-name: regenie-ntprobnp
#   labels: {}
#   last-update: '2024-09-27 13:30:45.448738'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/regenie-ntprobnp/jon126/20240927/123944/regenie-nt--jon126--240927-123947-19-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_ntprobnp/jon126/20240927/results/1
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 1000
#     cpu_platform: ''
#     disk-size: 200
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-6daa8f469d5e11e979a11ddfd4d9abd0
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-f
#     zones: []
#   script: "\nset -o pipefail \nset -o errexit\n\nplink     --bed \"${bedfile}\"  \
#     \   --bim \"${bimfile}\"     --fam \"${famfile}\"     --maf 0.01     --mac 100\
#     \     --geno 0.01     --hwe 1e-15     --indep-pairwise 1000 100 0.8     --write-snplist\
#     \     --out qc_ldpruned_snps_\"${chr}\"\n\nexport output=\"qc_ldpruned_snps_${chr}.snplist\"\
#     \nmv ${output} ${OUTPUT_PATH}\n"
#   script-name: 1_regenie_plinkprep.sh
#   start-time: '2024-09-27 12:39:57.537360'
#   status: CANCELED
#   status-detail: The operation was cancelled
#   status-message: The operation was cancelled
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8

# %%
#Look at log file
# !gsutil cp gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241001/113152/1-regenie---jon126--241001-113153-36-task-None.log ./
# Out:
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241001/113152/1-regenie---jon126--241001-113153-36-task-None.log...
# / [1 files][266.9 KiB/266.9 KiB]
# Operation completed over 1 objects/266.9 KiB.

# %%
#Cancel running jobs
# !ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --jobs '*' --users 'jon126' --location us-central1
# Out:
# Delete running jobs:
#   user:
#     {'jon126'}
#
#   job-id:
#     ['*']
#
# Found 0 tasks to delete.
# 0 jobs deleted

# %% [markdown]
# ## REGENIE GWAS Step

# %% [markdown]
# ### DSub Parameter Setting
#
# This requires modification for each different phenotype you run.

# %%
## MODIFY FOR FULL DATA RUN 
JOB_NAME='REGENIE_ntprobnp'
PHENOTYPE='ntprobnp'

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env JOB_NAME={JOB_NAME}
# %env PHENOTYPE={PHENOTYPE}
# Out:
# env: JOB_NAME=REGENIE_ntprobnp

# %%
## Analysis Results Folder 
line_count_results_folder = os.path.join(
    os.getenv('WORKSPACE_BUCKET'),
    'dsub',
    'results',
    JOB_NAME,
    USER_NAME,
    datetime.now().strftime('%Y%m%d'))

line_count_results_folder
# Out:
# 'gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_ntprobnp/jon126/20240927'

# %%
## Where the output files will go
output_files = os.path.join(line_count_results_folder, "results")
print(output_files)

OUTPUT_FILES = output_files

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env OUTPUT_FILES={OUTPUT_FILES}
# Out:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_ntprobnp/jon126/20240927/results
# env: OUTPUT_FILES=gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_ntprobnp/jon126/20240927/results

# %% [markdown]
# ### REGENIE Bash Script
#
# This details and writes out a .sh script in the local Jupyter disk and then uploads it to GCP Bucket in order for dsub to run it.

# %%
#This is the actual REGENIE bash script
filename2='2_regenie_aous_pp.sh'

script = '''
set -o pipefail 
set -o errexit

#This defines the actual bed_prefix, assuming localisation of the input bed/bim/fam files

echo "${bedfile}"
echo "${bimfile}"
echo "${famfile}"

bed_prefix="/mnt/data/input/gs/fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr"${chrom}" 

regenie \
    --step 1 \
    --bed "${bed_prefix}" \
    --phenoFile "${pheno_file}" \
    --phenoCol "${pheno}" \
    --covarFile "${cov_file}" \
    --catCovarList sex \
    --covarColList ht, wt, pc1, pc2, pc3, pc4, pc5, pc6, pc7, pc8, pc9, pc10, age_"${pheno}" \
    --bsize 1000 \
    --extract "${step1_snplist}" \
    --verbose \
    --"${trait}" \ 
    --apply-rint \
    --ref-first \
    --out "${pheno}"_step1_chr"${chrom}"

#regenie pt 2
regenie \
    --step 2 \
    --bed "${bed_prefix}" \
    --phenoFile "${pheno_file}" \
    --phenoCol "${pheno}" \
    --covarFile "${cov_file}" \
    --catCovarList sex \
    --covarColList ht, wt, pc1, pc2, pc3, pc4, pc5, pc6, pc7, pc8, pc9, pc10, age_"${pheno}" \
    --pred "${pheno}"_step1_chr"${chrom}"_pred.list \
    --bsize 1000 \
    --verbose \
    --"${trait}" \
    --apply-rint \
    --ref-first \
    --out "${pheno}"_step2_chr"${chrom}"

export regenie_results="${pheno}_step2_chr${chrom}.regenie"
echo "regenie_results: ${regenie_results}"
mv ${regenie_results} ${OUTPUT_PATH}
'''

with open(filename2,'w') as fp:
    fp.write(script)

# %%
#Upload to GCP Bucket
# !gsutil cp ./2_regenie_aous_pp.sh {my_bucket}/dsub/scripts/
# Out:
# Copying file://./1_regenie_plinkprep.sh [Content-Type=text/x-sh]...
# Copying file://./2_regenie_aous_pp.sh [Content-Type=text/x-sh]...
# CommandException: No URLs matched: -I

# %%
#Check the files are there
# !gsutil ls {my_bucket}/dsub/scripts/*.sh
# Out:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/1_regenie_plinkprep.sh
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/2_regenie_aous_pp.sh

# %% [markdown]
# ### Dsub Submission Script for REGENIE
#
# Note that all `--input` files have to be in double quotations
# whereas all `--env` environmental variables (for dsub) are NOT in quotations e.g `--env chrom=${chromo}` so if you need to use a Bash environmental variable for `--env` (in dsub) you remove the double quotes e.g `--env GOOGLE_PROJECT=${GOOGLE_PROJECT}`
#
# Bash environmental variables are in `"${...}"` format

# %%
# !echo "${ARTIFACT_REGISTRY_DOCKER_REPO}" #Base location for public Docker images via Dockerhub
# Out:
# us-central1-docker.pkg.dev/all-of-us-rw-prod/aou-rw-gar-remote-repo-docker-prod

# %%
#This submits the job btw for each chromosome!
# %%bash --out LINE_COUNT_JOB_ID

# Get a shorter username to leave more characters for the job name.
DSUB_USER_NAME="$(echo "${OWNER_EMAIL}" | cut -d@ -f1)"

# For AoU RWB projects network name is "network".
AOU_NETWORK=network
AOU_SUBNETWORK=subnetwork

MACHINE_TYPE="n2-standard-4"
BASH_SCRIPT="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/2_regenie_aous_pp.sh" #From above command

# Python is 'right side limited' wherein the last value is not included
# To run the regression across all chromosomes, set lower to 1 and upper to 23
# To run across one chromosome, set lower to the chomosome-of-interest and upper to the following

LOWER=1
UPPER=23
for ((chromo=$LOWER;chromo<$UPPER;chromo+=1))
do
    dsub \
    --provider google-cls-v2 \
    --user-project "${GOOGLE_PROJECT}" \
    --project "${GOOGLE_PROJECT}" \
    --image "${ARTIFACT_REGISTRY_DOCKER_REPO}/skoyamamd/regenie_3.4.1:latest" \
    --network "${AOU_NETWORK}" \
    --subnetwork "${AOU_SUBNETWORK}" \
    --service-account "$(gcloud config get-value account)" \
    --user "${DSUB_USER_NAME}" \
    --regions us-central1 \
    --logging "${WORKSPACE_BUCKET}/dsub/logs/{job-name}/{user-id}/$(date +'%Y%m%d/%H%M%S')/{job-id}-{task-id}-{task-attempt}.log" \
    "$@" \
    --preemptible \
    --boot-disk-size 1000 \
    --machine-type ${MACHINE_TYPE} \
    --name "${JOB_NAME}" \
    --script "${BASH_SCRIPT}" \
    --env GOOGLE_PROJECT=${GOOGLE_PROJECT} \
    --input bedfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.bed" \
    --input bimfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.bim" \
    --input famfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.fam" \
    --input pheno_file="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/data/pp_regenie_pheno.tsv" \
    --input cov_file="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/data/pp_regenie_covar.tsv" \
    --env chrom=${chromo} \
    --env pheno=${PHENOTYPE} \ 
    --env trait=qt \
    --output-recursive OUTPUT_PATH="${OUTPUT_FILES}/${chromo}"
done
# Out:
# Job properties:
#   job-id: regenie-nt--jon126--240927-123947-19
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/2520027973218601661
# Launched job-id: regenie-nt--jon126--240927-123947-19
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123947-19' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123947-19' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-123949-26
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/16075055557443499835
# Launched job-id: regenie-nt--jon126--240927-123949-26
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123949-26' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123949-26' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-123951-25
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/4914562099397583627
# Launched job-id: regenie-nt--jon126--240927-123951-25
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123951-25' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123951-25' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-123953-24
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/2615862707555848732
# Launched job-id: regenie-nt--jon126--240927-123953-24
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123953-24' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123953-24' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-123955-19
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/11636284146220376339
# Launched job-id: regenie-nt--jon126--240927-123955-19
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123955-19' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123955-19' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-123957-13
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/4139930053508649753
# Launched job-id: regenie-nt--jon126--240927-123957-13
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123957-13' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123957-13' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-123959-11
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/5191880674194698349
# Launched job-id: regenie-nt--jon126--240927-123959-11
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123959-11' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-123959-11' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124001-01
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/10290111967220811339
# Launched job-id: regenie-nt--jon126--240927-124001-01
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124001-01' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124001-01' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124002-94
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/7344639624501555720
# Launched job-id: regenie-nt--jon126--240927-124002-94
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124002-94' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124002-94' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124004-88
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/5094167922951910455
# Launched job-id: regenie-nt--jon126--240927-124004-88
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124004-88' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124004-88' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124006-85
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/2455109536663932920
# Launched job-id: regenie-nt--jon126--240927-124006-85
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124006-85' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124006-85' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124008-79
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/8049571936380176431
# Launched job-id: regenie-nt--jon126--240927-124008-79
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124008-79' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124008-79' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124010-74
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/13772002910211626535
# Launched job-id: regenie-nt--jon126--240927-124010-74
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124010-74' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124010-74' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124012-69
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/12284064959900707483
# Launched job-id: regenie-nt--jon126--240927-124012-69
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124012-69' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124012-69' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124014-70
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/12738233753242264589
# Launched job-id: regenie-nt--jon126--240927-124014-70
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124014-70' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124014-70' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124016-75
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/16889090863307769957
# Launched job-id: regenie-nt--jon126--240927-124016-75
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124016-75' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124016-75' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124018-67
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/16436270089750705429
# Launched job-id: regenie-nt--jon126--240927-124018-67
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124018-67' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124018-67' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124020-66
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/9127395860847721178
# Launched job-id: regenie-nt--jon126--240927-124020-66
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124020-66' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124020-66' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124022-58
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/1309257568376867504
# Launched job-id: regenie-nt--jon126--240927-124022-58
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124022-58' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124022-58' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124024-56
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/11206707269483568069
# Launched job-id: regenie-nt--jon126--240927-124024-56
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124024-56' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124024-56' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124026-45
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/7188483470483728656
# Launched job-id: regenie-nt--jon126--240927-124026-45
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124026-45' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124026-45' --users 'jon126'
# Job properties:
#   job-id: regenie-nt--jon126--240927-124028-35
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/18348208331961758513
# Launched job-id: regenie-nt--jon126--240927-124028-35
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124028-35' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--240927-124028-35' --users 'jon126'

# %%
# Check the status of your job submissions

# !dstat \
    --provider google-cls-v2 \
    --project terra-vpc-sc-4e1b6fe8 \
    --location us-central1 \
    --jobs '*' \
    --users 'jon126' \
    --status '*' \
   # --full
# Out:
# Job Name         Status                          Last Update
# ---------------  ------------------------------  --------------
# regenie-ntpr...  Started running "user-command"  09-27 13:17:02
# regenie-ntpr...  Started running "user-command"  09-27 13:15:38
# regenie-ntpr...  Started running "localization"  09-27 12:56:17
# regenie-ntpr...  Started running "localization"  09-27 12:57:12
# regenie-ntpr...  Started running "localization"  09-27 12:55:47
# regenie-ntpr...  Started running "localization"  09-27 12:56:08
# regenie-ntpr...  Started running "localization"  09-27 12:55:28
# regenie-ntpr...  Started running "localization"  09-27 12:54:41
# regenie-ntpr...  Started running "localization"  09-27 12:55:50
# regenie-ntpr...  Started running "localization"  09-27 12:55:30
# regenie-ntpr...  Started running "localization"  09-27 12:55:49
# regenie-ntpr...  Started running "localization"  09-27 12:55:35
# regenie-ntpr...  Started running "localization"  09-27 12:54:30
# regenie-ntpr...  Started running "localization"  09-27 12:55:54
# regenie-ntpr...  worker was terminated           09-27 13:11:59
# regenie-ntpr...  Started running "localization"  09-27 12:54:15
# regenie-ntpr...  Started running "localization"  09-27 12:56:25
# regenie-ntpr...  Started running "localization"  09-27 12:55:34
# regenie-ntpr...  Started running "localization"  09-27 12:54:50
# regenie-ntpr...  Started running "localization"  09-27 12:56:12
# regenie-ntpr...  Started running "localization"  09-27 12:54:22
# regenie-ntpr...  Started running "localization"  09-27 12:55:27
