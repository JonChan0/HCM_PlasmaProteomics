# %% [markdown]
# # GWAS via REGENIE for PP
#
# This uses dsub (as opposed to WDL + Cromwell) to submit bash scripts corresponding to REGENIE for GWAS.
#
# Template for code: https://workbench.researchallofus.org/workspaces/aou-rw-5981f9dc/aouldlgwasregeniedsubctv6duplicate/analysis/preview/4.0_regenie_dsub_HP_TM.ipynb
# i.e the GWAS for LDL-C done by Bick et al, 2024
#
# Modified for my applications.

# %%
## Python Package Import
import sys
import os 
import numpy as np
import pandas as pd
from datetime import datetime

##Ensuring dsub is up to date
# !pip3 install --upgrade dsub
# Out:
# Requirement already satisfied: dsub in /home/jupyter/.local/lib/python3.10/site-packages (0.5.0)
# Requirement already satisfied: funcsigs==1.0.2 in /opt/conda/lib/python3.10/site-packages (from dsub) (1.0.2)
# Requirement already satisfied: google-api-core<=2.19.0,>=2.7.3 in /opt/conda/lib/python3.10/site-packages (from dsub) (2.11.1)
# Requirement already satisfied: google-api-python-client<=2.131.0,>=2.47.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (2.131.0)
# Requirement already satisfied: google-auth-httplib2<=0.2.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.2.0)
# Requirement already satisfied: google-auth<=2.29.0,>=2.6.6 in /opt/conda/lib/python3.10/site-packages (from dsub) (2.22.0)
# Requirement already satisfied: google-cloud-batch<=0.17.20 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.17.20)
# Requirement already satisfied: httplib2<=0.22.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.21.0)
# Requirement already satisfied: mock<=5.1.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (5.1.0)
# Requirement already satisfied: parameterized<=0.9.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.9.0)
# Requirement already satisfied: protobuf<=5.26.0,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (3.19.6)
# Requirement already satisfied: pyasn1-modules<=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.2.7)
# Requirement already satisfied: pyasn1<=0.6.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.4.8)
# Requirement already satisfied: python-dateutil<=2.9.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (2.8.2)
# Requirement already satisfied: pytz<=2024.1 in /opt/conda/lib/python3.10/site-packages (from dsub) (2023.3)
# Requirement already satisfied: pyyaml<=6.0.1 in /opt/conda/lib/python3.10/site-packages (from dsub) (6.0.1)
# Requirement already satisfied: rsa<=4.9 in /opt/conda/lib/python3.10/site-packages (from dsub) (4.9)
# Requirement already satisfied: tabulate<=0.9.0 in /opt/conda/lib/python3.10/site-packages (from dsub) (0.9.0)
# Requirement already satisfied: tenacity<=8.2.3 in /opt/conda/lib/python3.10/site-packages (from dsub) (8.2.3)
# Requirement already satisfied: uritemplate<=4.1.1 in /opt/conda/lib/python3.10/site-packages (from dsub) (3.0.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core<=2.19.0,>=2.7.3->dsub) (1.60.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /opt/conda/lib/python3.10/site-packages (from google-api-core<=2.19.0,>=2.7.3->dsub) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<=2.29.0,>=2.6.6->dsub) (4.2.4)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<=2.29.0,>=2.6.6->dsub) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<=2.29.0,>=2.6.6->dsub) (1.26.15)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-batch<=0.17.20->dsub) (1.22.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.10/site-packages (from httplib2<=0.22.0->dsub) (3.0.9)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-batch<=0.17.20->dsub) (1.48.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-batch<=0.17.20->dsub) (1.48.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<=2.19.0,>=2.7.3->dsub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<=2.19.0,>=2.7.3->dsub) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core<=2.19.0,>=2.7.3->dsub) (2024.2.2)

# %%
#Defining environment variables
# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env JOB_ID={LINE_COUNT_JOB_ID}
## Defining necessary pathways
my_bucket = os.environ['WORKSPACE_BUCKET']
## Setting for running dsub jobs
pd.set_option('display.max_colwidth', 0)

USER_NAME = os.getenv('OWNER_EMAIL').split('@')[0].replace('.','-')

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env USER_NAME={USER_NAME}
# Out:
# env: JOB_ID={LINE_COUNT_JOB_ID}
# env: USER_NAME=jon126

# %% [markdown]
# ## 1.1a PLINK QC Step
#
# This runs the code and submits the job for each chromosome to run the preparatory QC step which is phenotype-agnostic.

# %%
## MODIFY FOR FULL DATA RUN 
JOB_NAME='1_regenie_plinkprep'

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env JOB_NAME={JOB_NAME}
# Out:
# env: JOB_NAME=1_regenie_plinkprep

# %%
## Analysis Results Folder 
line_count_results_folder = os.path.join(
    os.getenv('WORKSPACE_BUCKET'),
    'dsub',
    'results',
    JOB_NAME,
    USER_NAME,
    datetime.now().strftime('%Y%m%d'))

line_count_results_folder
# Out:
# 'gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241015'

# %%
## Where the output files will go
output_files = os.path.join(line_count_results_folder, "results")
print(output_files)

OUTPUT_FILES = output_files

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env OUTPUT_FILES={OUTPUT_FILES}
# Out:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241015/results
# env: OUTPUT_FILES=gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241015/results

# %%
#This is the plink preparatory in REGENIE 
filename='1_regenie_plinkprep.sh'

script = '''

set -o pipefail 
set -o errexit

plink \
    --bed "${bedfile}" \
    --bim "${bimfile}" \
    --fam "${famfile}" \
    --geno 0.01 \
    --hwe 1e-15 \
    --indep-pairwise 1000 100 0.8 \
    --write-snplist \
    --memory 14000 \
    --out qc_ldpruned_snps_chr"${chr}"

export output_snplist="qc_ldpruned_snps_chr${chr}.snplist" 
export output_ldprune_in="qc_ldpruned_snps_chr${chr}.prune.in" 
export output_ldprune_out="qc_ldpruned_snps_chr${chr}.prune.out"

mv ${output_snplist} ${output_ldprune_in} ${output_ldprune_out} -t ${OUTPUT_PATH}
'''

with open(filename,'w') as fp:
    fp.write(script)

# %%
# !gsutil cp ./1_regenie_plinkprep.sh {my_bucket}/dsub/scripts/
# Out:
# Copying file://./1_regenie_plinkprep.sh [Content-Type=text/x-sh]...
# / [1 files][  527.0 B/  527.0 B]
# Operation completed over 1 objects/527.0 B.

# %%
#Check the file is there
# !gsutil ls {my_bucket}/dsub/scripts/*.sh
# Out:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/1_regenie_plinkprep.sh
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/2_regenie_aous_pp.sh

# %%
# !gsutil -u $GOOGLE_PROJECT ls -lh gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/
# Out:
# 423.72 GiB  2023-09-26T17:40:39Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr1.bed
# 356.34 MiB  2023-09-26T13:42:19Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr1.bim
#   4.45 MiB  2023-09-26T13:41:54Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr1.fam
# 272.02 GiB  2023-09-26T16:05:59Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr10.bed
# 238.88 MiB  2023-09-26T13:42:14Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr10.bim
#   4.45 MiB  2023-09-26T13:41:52Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr10.fam
# 253.58 GiB  2023-09-26T15:59:01Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr11.bed
# 217.12 MiB  2023-09-26T13:42:15Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr11.bim
#   4.45 MiB  2023-09-26T13:42:06Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr11.fam
# 256.77 GiB  2023-09-26T15:57:06Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr12.bed
# 223.32 MiB  2023-09-26T13:42:19Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr12.bim
#   4.45 MiB  2023-09-26T13:41:52Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr12.fam
# 183.37 GiB  2023-09-26T15:19:14Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr13.bed
# 159.52 MiB  2023-09-26T13:42:19Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr13.bim
#   4.45 MiB  2023-09-26T13:41:56Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr13.fam
#  170.6 GiB  2023-09-26T15:10:23Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr14.bed
# 145.93 MiB  2023-09-26T13:42:17Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr14.bim
#   4.45 MiB  2023-09-26T13:42:08Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr14.fam
# 164.79 GiB  2023-09-26T15:09:08Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr15.bed
# 141.54 MiB  2023-09-26T13:42:10Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr15.bim
#   4.45 MiB  2023-09-26T13:41:56Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr15.fam
# 189.84 GiB  2023-09-26T15:20:16Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr16.bed
# 164.26 MiB  2023-09-26T13:42:13Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr16.bim
#   4.45 MiB  2023-09-26T13:41:55Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr16.fam
# 175.42 GiB  2023-09-26T15:12:08Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr17.bed
#  155.4 MiB  2023-09-26T13:42:19Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr17.bim
#   4.45 MiB  2023-09-26T13:41:55Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr17.fam
# 146.33 GiB  2023-09-26T15:01:04Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr18.bed
# 125.75 MiB  2023-09-26T13:42:17Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr18.bim
#   4.45 MiB  2023-09-26T13:41:54Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr18.fam
# 146.89 GiB  2023-09-26T15:03:42Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr19.bed
# 130.99 MiB  2023-09-26T13:42:13Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr19.bim
#   4.45 MiB  2023-09-26T13:42:02Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr19.fam
#  451.4 GiB  2023-09-26T17:52:38Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr2.bed
#  379.7 MiB  2023-09-26T13:42:21Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr2.bim
#   4.45 MiB  2023-09-26T13:42:01Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr2.fam
# 127.59 GiB  2023-09-26T14:51:19Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr20.bed
# 113.25 MiB  2023-09-26T13:42:10Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr20.bim
#   4.45 MiB  2023-09-26T13:41:56Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr20.fam
#  87.92 GiB  2023-09-26T14:31:51Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bed
#     79 MiB  2023-09-26T13:42:04Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bim
#   4.45 MiB  2023-09-26T13:41:54Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.fam
#  91.22 GiB  2023-09-26T14:34:57Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr22.bed
#  83.07 MiB  2023-09-26T13:42:10Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr22.bim
#   4.45 MiB  2023-09-26T13:41:56Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr22.fam
#  359.1 GiB  2023-09-26T16:59:04Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr3.bed
# 294.14 MiB  2023-09-26T13:42:20Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr3.bim
#   4.45 MiB  2023-09-26T13:41:53Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr3.fam
# 368.49 GiB  2023-09-26T17:00:01Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr4.bed
# 306.51 MiB  2023-09-26T13:42:19Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr4.bim
#   4.45 MiB  2023-09-26T13:41:56Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr4.fam
# 332.63 GiB  2023-09-26T16:38:29Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr5.bed
# 273.51 MiB  2023-09-26T13:42:21Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr5.bim
#   4.45 MiB  2023-09-26T13:42:06Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr5.fam
# 326.86 GiB  2023-09-26T16:36:35Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr6.bed
#    272 MiB  2023-09-26T13:42:18Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr6.bim
#   4.45 MiB  2023-09-26T13:41:54Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr6.fam
# 321.96 GiB  2023-09-26T16:34:16Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr7.bed
# 272.91 MiB  2023-09-26T13:42:19Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr7.bim
#   4.45 MiB  2023-09-26T13:42:00Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr7.fam
# 291.87 GiB  2023-09-26T16:14:59Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr8.bed
# 240.71 MiB  2023-09-26T13:42:17Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr8.bim
#   4.45 MiB  2023-09-26T13:41:57Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr8.fam
# 239.03 GiB  2023-09-26T15:47:02Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr9.bed
# 198.15 MiB  2023-09-26T13:42:15Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr9.bim
#   4.45 MiB  2023-09-26T13:41:58Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr9.fam
# 260.09 GiB  2023-09-26T16:03:11Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chrX.bed
# 219.32 MiB  2023-09-26T13:42:13Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chrX.bim
#   4.45 MiB  2023-09-26T13:42:01Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chrX.fam
#  29.29 GiB  2023-09-26T13:57:25Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chrY.bed
#  28.09 MiB  2023-09-26T13:41:58Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chrY.bim
#   4.45 MiB  2023-09-26T13:41:53Z  gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chrY.fam
# TOTAL: 72 objects, 6094103724696 bytes (5.54 TiB)

# %%
# %%bash --out LINE_COUNT_JOB_ID
# #This submits the job btw for each chromosome!
#
# # Get a shorter username to leave more characters for the job name.
# DSUB_USER_NAME="$(echo "${OWNER_EMAIL}" | cut -d@ -f1)"
#
# # For AoU RWB projects network name is "network".
# AOU_NETWORK=network
# AOU_SUBNETWORK=subnetwork
#
# MACHINE_TYPE="n2-standard-4"
# BASH_SCRIPT="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/1_regenie_plinkprep.sh" #From above command
#
# # Python is 'right side limited' wherein the last value is not included
# # To run the regression across all chromosomes, set lower to 1 and upper to 23
# # To run across one chromosome, set lower to the chomosome-of-interest and upper to the following
#
# # LOWER=1
# # UPPER=23
#
# #Test on 1 chromosome first
# LOWER=12
# UPPER=13
# for ((chromo=$LOWER;chromo<$UPPER;chromo+=1))
# do
#     dsub \
#     --provider google-cls-v2 \
#     --user-project "${GOOGLE_PROJECT}" \
#     --project "${GOOGLE_PROJECT}" \
#     --image "us.gcr.io/broad-dsp-gcr-public/terra-jupyter-aou:2.2.14" \
#     --network "${AOU_NETWORK}" \
#     --subnetwork "${AOU_SUBNETWORK}" \
#     --service-account "$(gcloud config get-value account)" \
#     --user "${DSUB_USER_NAME}" \
#     --regions us-central1 \
#     --logging "${WORKSPACE_BUCKET}/dsub/logs/{job-name}/{user-id}/$(date +'%Y%m%d/%H%M%S')/{job-id}-{task-id}-{task-attempt}.log" \
#     "$@" \
#     --preemptible \
#     --disk-size 1000 \
#     --boot-disk-size 100 \
#     --machine-type ${MACHINE_TYPE} \
#     --name "${JOB_NAME}" \
#     --script "${BASH_SCRIPT}" \
#     --env GOOGLE_PROJECT=${GOOGLE_PROJECT} \
#     --input bedfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.bed" \
#     --input bimfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.bim" \
#     --input famfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.fam" \
#     --env chr=${chromo} \
#     --output-recursive OUTPUT_PATH="${OUTPUT_FILES}/${chromo}"
# done
# Out:
# Job properties:
#   job-id: 1-regenie---jon126--241010-120423-08
#   job-name: 1-regenie-plinkprep
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/11449612967915098292
# Launched job-id: 1-regenie---jon126--241010-120423-08
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs '1-regenie---jon126--241010-120423-08' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs '1-regenie---jon126--241010-120423-08' --users 'jon126'

# %%
# Check the status of your job submissions
# !dstat \
    --provider google-cls-v2 \
    --project terra-vpc-sc-4e1b6fe8 \
    --location us-central1 \
    --jobs '*' \
    --users 'jon126' \
    --status '*' \
    --age 3d
# Out:
# Job Name         Status                                      Last Update
# ---------------  ------------------------------------------  --------------
# 1-regenie-pl...  Success                                     10-10 22:13:50
# 1-regenie-pl...  Success                                     10-10 23:54:04
# 1-regenie-pl...  Success                                     10-09 18:52:06
# 1-regenie-pl...  worker was terminated                       10-09 14:31:17
# 1-regenie-pl...  Success                                     10-09 21:39:26
# 1-regenie-pl...  worker was terminated                       10-09 17:44:43
# 1-regenie-pl...  Success                                     10-10 00:47:23
# 1-regenie-pl...  Success                                     10-08 18:21:34
# 1-regenie-pl...  Success                                     10-08 18:32:59
# 1-regenie-pl...  Success                                     10-08 20:02:00
# 1-regenie-pl...  Success                                     10-08 20:14:18
# 1-regenie-pl...  Success                                     10-08 21:48:01
# 1-regenie-pl...  worker was terminated                       10-08 15:54:42
# 1-regenie-pl...  Success                                     10-09 00:00:03
# 1-regenie-pl...  Success                                     10-08 21:33:58
# 1-regenie-pl...  Success                                     10-08 22:08:15
# 1-regenie-pl...  Success                                     10-08 23:15:03
# 1-regenie-pl...  worker was terminated                       10-08 17:34:31
# 1-regenie-pl...  Success                                     10-09 03:21:31
# 1-regenie-pl...  worker was terminated                       10-08 21:40:11
# 1-regenie-pl...  Success                                     10-09 01:00:00
# 1-regenie-pl...  worker was terminated                       10-08 15:10:38
# 1-regenie-pl...  Success                                     10-09 04:43:07
# 1-regenie-pl...  Success                                     10-09 07:03:52
# 1-regenie-pl...  worker was terminated                       10-08 18:02:31
# 1-regenie-pl...  Success                                     10-09 06:11:14
# 1-regenie-pl...  Success                                     10-09 06:20:19
# 1-regenie-pl...  Success                                     10-09 12:07:10
# 1-regenie-pl...  Success                                     10-09 08:21:23
# 1-regenie-pl...  Stopped running "user-command": exit st...  10-08 15:03:21
# 1-regenie-pl...  Stopped running "user-command": exit st...  10-08 15:03:08
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:10
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:10
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:10
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 15:09:09
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27
# 1-regenie-pl...  The operation was cancelled                 10-08 14:28:27

# %%
# Check the status of your job submissions

# !dstat \
    --provider google-cls-v2 \
    --project terra-vpc-sc-4e1b6fe8 \
    --location us-central1 \
    --jobs '*' \
    --users 'jon126' \
    --status 'FAILURE' \
    --full \
    --age 2d
# Out:
# - create-time: '2024-10-09 11:43:14.656295'
#   dsub-version: v0-5-0
#   end-time: '2024-10-09 14:31:17.649095'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chr: '12'
#   events:
#   - name: start
#     start-time: 2024-10-09 11:43:21.506790+00:00
#   - name: pulling-image
#     start-time: 2024-10-09 11:43:55.122212+00:00
#   - name: localizing-files
#     start-time: 2024-10-09 11:57:43.376502+00:00
#   - name: running-docker
#     start-time: 2024-10-09 12:49:15.598245+00:00
#   - name: 'Execution failed: worker was terminated'
#     start-time: 2024-10-09 14:31:17.112276+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr12.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr12.bim
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr12.fam
#   internal-id: projects/282373700333/locations/us-central1/operations/12100942583103545854
#   job-id: 1-regenie---jon126--241009-114314-54
#   job-name: 1-regenie-plinkprep
#   labels: {}
#   last-update: '2024-10-09 14:31:17.649095'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241009/114313/1-regenie---jon126--241009-114314-54-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/12
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 500
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-b90ab44d54fa2bdd6adde7538d3b9fd1
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-f
#     zones: []
#   script: "\n\nset -o pipefail \nset -o errexit\n\nplink     --bed \"${bedfile}\"\
#     \     --bim \"${bimfile}\"     --fam \"${famfile}\"     --geno 0.01     --hwe\
#     \ 1e-15     --indep-pairwise 1000 100 0.8     --write-snplist     --memory 14000\
#     \     --out qc_ldpruned_snps_chr\"${chr}\"\n\nexport output_snplist=\"qc_ldpruned_snps_chr${chr}.snplist\"\
#     \ \nexport output_ldprune_in=\"qc_ldpruned_snps_chr${chr}.prune.in\" \nexport\
#     \ output_ldprune_out=\"qc_ldpruned_snps_chr${chr}.prune.out\"\n\nmv ${output_snplist}\
#     \ ${output_ldprune_in} ${output_ldprune_out} -t ${OUTPUT_PATH}\n"
#   script-name: 1_regenie_plinkprep.sh
#   start-time: '2024-10-09 11:43:21.506790'
#   status: FAILURE
#   status-detail: 'Execution failed: worker was terminated'
#   status-message: worker was terminated
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8
# - create-time: '2024-10-09 11:42:38.232752'
#   dsub-version: v0-5-0
#   end-time: '2024-10-09 17:44:43.963759'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chr: '8'
#   events:
#   - name: start
#     start-time: 2024-10-09 11:42:48.179361+00:00
#   - name: pulling-image
#     start-time: 2024-10-09 11:43:23.180582+00:00
#   - name: localizing-files
#     start-time: 2024-10-09 11:56:36.378098+00:00
#   - name: running-docker
#     start-time: 2024-10-09 12:36:57.132504+00:00
#   - name: 'Execution failed: worker was terminated'
#     start-time: 2024-10-09 17:44:43.583128+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr8.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr8.bim
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr8.fam
#   internal-id: projects/282373700333/locations/us-central1/operations/16903125202916717857
#   job-id: 1-regenie---jon126--241009-114238-10
#   job-name: 1-regenie-plinkprep
#   labels: {}
#   last-update: '2024-10-09 17:44:43.963759'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241009/114237/1-regenie---jon126--241009-114238-10-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/8
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 500
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-0975d48ce80078dc630c08b177185143
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-b
#     zones: []
#   script: "\n\nset -o pipefail \nset -o errexit\n\nplink     --bed \"${bedfile}\"\
#     \     --bim \"${bimfile}\"     --fam \"${famfile}\"     --geno 0.01     --hwe\
#     \ 1e-15     --indep-pairwise 1000 100 0.8     --write-snplist     --memory 14000\
#     \     --out qc_ldpruned_snps_chr\"${chr}\"\n\nexport output_snplist=\"qc_ldpruned_snps_chr${chr}.snplist\"\
#     \ \nexport output_ldprune_in=\"qc_ldpruned_snps_chr${chr}.prune.in\" \nexport\
#     \ output_ldprune_out=\"qc_ldpruned_snps_chr${chr}.prune.out\"\n\nmv ${output_snplist}\
#     \ ${output_ldprune_in} ${output_ldprune_out} -t ${OUTPUT_PATH}\n"
#   script-name: 1_regenie_plinkprep.sh
#   start-time: '2024-10-09 11:42:48.179361'
#   status: FAILURE
#   status-detail: 'Execution failed: worker was terminated'
#   status-message: worker was terminated
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8
# - create-time: '2024-10-08 15:10:10.632810'
#   dsub-version: v0-5-0
#   end-time: '2024-10-08 15:54:42.082885'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chr: '17'
#   events:
#   - name: start
#     start-time: 2024-10-08 15:10:19.501295+00:00
#   - name: pulling-image
#     start-time: 2024-10-08 15:10:59.394854+00:00
#   - name: localizing-files
#     start-time: 2024-10-08 15:25:33.510942+00:00
#   - name: 'Execution failed: worker was terminated'
#     start-time: 2024-10-08 15:54:41.694219+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr17.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr17.bim
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr17.fam
#   internal-id: projects/282373700333/locations/us-central1/operations/14913856465982285342
#   job-id: 1-regenie---jon126--241008-151010-53
#   job-name: 1-regenie-plinkprep
#   labels: {}
#   last-update: '2024-10-08 15:54:42.082885'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241008/151009/1-regenie---jon126--241008-151010-53-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241008/results/17
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 500
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-f184d1c867db3cce86454aa37b81ff27
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-f
#     zones: []
#   script: "\n\nset -o pipefail \nset -o errexit\n\nplink     --bed \"${bedfile}\"\
#     \     --bim \"${bimfile}\"     --fam \"${famfile}\"     --geno 0.01     --hwe\
#     \ 1e-15     --indep-pairwise 1000 100 0.8     --write-snplist     --memory 14000\
#     \     --out qc_ldpruned_snps_chr\"${chr}\"\n\nexport output_snplist=\"qc_ldpruned_snps_chr${chr}.snplist\"\
#     \ \nexport output_ldprune_in=\"qc_ldpruned_snps_chr${chr}.prune.in\" \nexport\
#     \ output_ldprune_out=\"qc_ldpruned_snps_chr${chr}.prune.out\"\n\nmv ${output_snplist}\
#     \ ${output_ldprune_in} ${output_ldprune_out} -t ${OUTPUT_PATH}\n"
#   script-name: 1_regenie_plinkprep.sh
#   start-time: '2024-10-08 15:10:19.501295'
#   status: FAILURE
#   status-detail: 'Execution failed: worker was terminated'
#   status-message: worker was terminated
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8
# - create-time: '2024-10-08 15:09:59.741166'
#   dsub-version: v0-5-0
#   end-time: '2024-10-08 17:34:31.575193'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chr: '12'
#   events:
#   - name: start
#     start-time: 2024-10-08 15:10:04.110821+00:00
#   - name: pulling-image
#     start-time: 2024-10-08 15:10:50.581971+00:00
#   - name: localizing-files
#     start-time: 2024-10-08 15:24:19.737019+00:00
#   - name: running-docker
#     start-time: 2024-10-08 16:25:12.663187+00:00
#   - name: 'Execution failed: worker was terminated'
#     start-time: 2024-10-08 17:34:31.140141+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr12.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr12.bim
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr12.fam
#   internal-id: projects/282373700333/locations/us-central1/operations/13668941383293836833
#   job-id: 1-regenie---jon126--241008-150959-63
#   job-name: 1-regenie-plinkprep
#   labels: {}
#   last-update: '2024-10-08 17:34:31.575193'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241008/150958/1-regenie---jon126--241008-150959-63-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241008/results/12
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 500
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-155ba97e402669929b197e085991383c
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-c
#     zones: []
#   script: "\n\nset -o pipefail \nset -o errexit\n\nplink     --bed \"${bedfile}\"\
#     \     --bim \"${bimfile}\"     --fam \"${famfile}\"     --geno 0.01     --hwe\
#     \ 1e-15     --indep-pairwise 1000 100 0.8     --write-snplist     --memory 14000\
#     \     --out qc_ldpruned_snps_chr\"${chr}\"\n\nexport output_snplist=\"qc_ldpruned_snps_chr${chr}.snplist\"\
#     \ \nexport output_ldprune_in=\"qc_ldpruned_snps_chr${chr}.prune.in\" \nexport\
#     \ output_ldprune_out=\"qc_ldpruned_snps_chr${chr}.prune.out\"\n\nmv ${output_snplist}\
#     \ ${output_ldprune_in} ${output_ldprune_out} -t ${OUTPUT_PATH}\n"
#   script-name: 1_regenie_plinkprep.sh
#   start-time: '2024-10-08 15:10:04.110821'
#   status: FAILURE
#   status-detail: 'Execution failed: worker was terminated'
#   status-message: worker was terminated
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8
# - create-time: '2024-10-08 15:09:55.292236'
#   dsub-version: v0-5-0
#   end-time: '2024-10-08 21:40:11.950467'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chr: '10'
#   events:
#   - name: start
#     start-time: 2024-10-08 15:10:04.110936+00:00
#   - name: pulling-image
#     start-time: 2024-10-08 15:10:40.841591+00:00
#   - name: localizing-files
#     start-time: 2024-10-08 15:24:23.476200+00:00
#   - name: running-docker
#     start-time: 2024-10-08 16:22:32.043320+00:00
#   - name: 'Execution failed: worker was terminated'
#     start-time: 2024-10-08 21:40:11.594173+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr10.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr10.bim
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr10.fam
#   internal-id: projects/282373700333/locations/us-central1/operations/16130041463084332821
#   job-id: 1-regenie---jon126--241008-150955-18
#   job-name: 1-regenie-plinkprep
#   labels: {}
#   last-update: '2024-10-08 21:40:11.950467'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241008/150954/1-regenie---jon126--241008-150955-18-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241008/results/10
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 500
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-e66124100cb4a909e05f435477857a46
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-b
#     zones: []
#   script: "\n\nset -o pipefail \nset -o errexit\n\nplink     --bed \"${bedfile}\"\
#     \     --bim \"${bimfile}\"     --fam \"${famfile}\"     --geno 0.01     --hwe\
#     \ 1e-15     --indep-pairwise 1000 100 0.8     --write-snplist     --memory 14000\
#     \     --out qc_ldpruned_snps_chr\"${chr}\"\n\nexport output_snplist=\"qc_ldpruned_snps_chr${chr}.snplist\"\
#     \ \nexport output_ldprune_in=\"qc_ldpruned_snps_chr${chr}.prune.in\" \nexport\
#     \ output_ldprune_out=\"qc_ldpruned_snps_chr${chr}.prune.out\"\n\nmv ${output_snplist}\
#     \ ${output_ldprune_in} ${output_ldprune_out} -t ${OUTPUT_PATH}\n"
#   script-name: 1_regenie_plinkprep.sh
#   start-time: '2024-10-08 15:10:04.110936'
#   status: FAILURE
#   status-detail: 'Execution failed: worker was terminated'
#   status-message: worker was terminated
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8
# - create-time: '2024-10-08 15:09:50.944451'
#   dsub-version: v0-5-0
#   end-time: '2024-10-08 15:10:38.992182'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chr: '8'
#   events:
#   - name: start
#     start-time: 2024-10-08 15:09:51.521268+00:00
#   - name: pulling-image
#     start-time: 2024-10-08 15:10:27.052270+00:00
#   - name: 'Execution failed: worker was terminated'
#     start-time: 2024-10-08 15:10:38.607584+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr8.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr8.bim
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr8.fam
#   internal-id: projects/282373700333/locations/us-central1/operations/13830268276148506366
#   job-id: 1-regenie---jon126--241008-150950-83
#   job-name: 1-regenie-plinkprep
#   labels: {}
#   last-update: '2024-10-08 15:10:38.992182'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241008/150949/1-regenie---jon126--241008-150950-83-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241008/results/8
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 500
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-b816953d06d0cea5f9bac74090047a24
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-b
#     zones: []
#   script: "\n\nset -o pipefail \nset -o errexit\n\nplink     --bed \"${bedfile}\"\
#     \     --bim \"${bimfile}\"     --fam \"${famfile}\"     --geno 0.01     --hwe\
#     \ 1e-15     --indep-pairwise 1000 100 0.8     --write-snplist     --memory 14000\
#     \     --out qc_ldpruned_snps_chr\"${chr}\"\n\nexport output_snplist=\"qc_ldpruned_snps_chr${chr}.snplist\"\
#     \ \nexport output_ldprune_in=\"qc_ldpruned_snps_chr${chr}.prune.in\" \nexport\
#     \ output_ldprune_out=\"qc_ldpruned_snps_chr${chr}.prune.out\"\n\nmv ${output_snplist}\
#     \ ${output_ldprune_in} ${output_ldprune_out} -t ${OUTPUT_PATH}\n"
#   script-name: 1_regenie_plinkprep.sh
#   start-time: '2024-10-08 15:09:51.521268'
#   status: FAILURE
#   status-detail: 'Execution failed: worker was terminated'
#   status-message: worker was terminated
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8
# - create-time: '2024-10-08 15:09:44.267588'
#   dsub-version: v0-5-0
#   end-time: '2024-10-08 18:02:31.094866'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chr: '5'
#   events:
#   - name: start
#     start-time: 2024-10-08 15:09:47.497749+00:00
#   - name: pulling-image
#     start-time: 2024-10-08 15:10:38.054159+00:00
#   - name: localizing-files
#     start-time: 2024-10-08 15:25:13.040459+00:00
#   - name: running-docker
#     start-time: 2024-10-08 17:00:02.377376+00:00
#   - name: 'Execution failed: worker was terminated'
#     start-time: 2024-10-08 18:02:30.749672+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr5.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr5.bim
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr5.fam
#   internal-id: projects/282373700333/locations/us-central1/operations/6820401369678020528
#   job-id: 1-regenie---jon126--241008-150944-15
#   job-name: 1-regenie-plinkprep
#   labels: {}
#   last-update: '2024-10-08 18:02:31.094866'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241008/150943/1-regenie---jon126--241008-150944-15-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241008/results/5
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 500
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-65f1e451ed89a0ced9414d8820453cfb
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-f
#     zones: []
#   script: "\n\nset -o pipefail \nset -o errexit\n\nplink     --bed \"${bedfile}\"\
#     \     --bim \"${bimfile}\"     --fam \"${famfile}\"     --geno 0.01     --hwe\
#     \ 1e-15     --indep-pairwise 1000 100 0.8     --write-snplist     --memory 14000\
#     \     --out qc_ldpruned_snps_chr\"${chr}\"\n\nexport output_snplist=\"qc_ldpruned_snps_chr${chr}.snplist\"\
#     \ \nexport output_ldprune_in=\"qc_ldpruned_snps_chr${chr}.prune.in\" \nexport\
#     \ output_ldprune_out=\"qc_ldpruned_snps_chr${chr}.prune.out\"\n\nmv ${output_snplist}\
#     \ ${output_ldprune_in} ${output_ldprune_out} -t ${OUTPUT_PATH}\n"
#   script-name: 1_regenie_plinkprep.sh
#   start-time: '2024-10-08 15:09:47.497749'
#   status: FAILURE
#   status-detail: 'Execution failed: worker was terminated'
#   status-message: worker was terminated
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8
# - create-time: '2024-10-08 14:29:55.230869'
#   dsub-version: v0-5-0
#   end-time: '2024-10-08 15:03:21.725990'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chr: '22'
#   events:
#   - name: start
#     start-time: 2024-10-08 14:30:01.229026+00:00
#   - name: pulling-image
#     start-time: 2024-10-08 14:30:38.484916+00:00
#   - name: localizing-files
#     start-time: 2024-10-08 14:43:07.701013+00:00
#   - name: running-docker
#     start-time: 2024-10-08 15:03:15.896013+00:00
#   - name: fail
#     start-time: 2024-10-08 15:03:17.688954+00:00
#   - name: 'Execution failed: generic::failed_precondition: while running "user-command":
#       unexpected exit status 5 was not ignored'
#     start-time: 2024-10-08 15:03:21.338567+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr22.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr22.bim
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr22.fam
#   internal-id: projects/282373700333/locations/us-central1/operations/7253940857462710775
#   job-id: 1-regenie---jon126--241008-142955-15
#   job-name: 1-regenie-plinkprep
#   labels: {}
#   last-update: '2024-10-08 15:03:21.725990'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241008/142954/1-regenie---jon126--241008-142955-15-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241008/results/22
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 500
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-c113028ad2cb5403761144a59c00e27d
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-b
#     zones: []
#   script: "\n\nset -o pipefail \nset -o errexit\n\nplink     --bed \"${bedfile}\"\
#     \     --bim \"${bimfile}\"     --fam \"${famfile}\"     --threads 3 \\ \n    --geno\
#     \ 0.01     --hwe 1e-15     --indep-pairwise 1000 100 0.8     --write-snplist \
#     \    --memory 14000     --out qc_ldpruned_snps_chr\"${chr}\"\n\nexport output_snplist=\"\
#     qc_ldpruned_snps_chr${chr}.snplist\" \nexport output_ldprune_in=\"qc_ldpruned_snps_chr${chr}.prune.in\"\
#     \ \nexport output_ldprune_out=\"qc_ldpruned_snps_chr${chr}.prune.out\"\n\nmv ${output_snplist}\
#     \ ${output_ldprune_in} ${output_ldprune_out} -t ${OUTPUT_PATH}\n"
#   script-name: 1_regenie_plinkprep.sh
#   start-time: '2024-10-08 14:30:01.229026'
#   status: FAILURE
#   status-detail: |
#     Error: --threads only accepts 1 parameter.
#     For more information, try "plink --help <flag name>" or "plink --help | more".
#   status-message: |-
#     Stopped running "user-command": exit status 5: Error: --threads only accepts 1 parameter.
#     For more information, try "plink --help <flag name>" or "plink --help | more".
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8
# - create-time: '2024-10-08 14:29:53.207710'
#   dsub-version: v0-5-0
#   end-time: '2024-10-08 15:03:08.205847'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chr: '21'
#   events:
#   - name: start
#     start-time: 2024-10-08 14:30:01.229213+00:00
#   - name: pulling-image
#     start-time: 2024-10-08 14:30:45.358445+00:00
#   - name: localizing-files
#     start-time: 2024-10-08 14:43:49.066533+00:00
#   - name: running-docker
#     start-time: 2024-10-08 15:03:01.805206+00:00
#   - name: fail
#     start-time: 2024-10-08 15:03:04.477343+00:00
#   - name: 'Execution failed: generic::failed_precondition: while running "user-command":
#       unexpected exit status 5 was not ignored'
#     start-time: 2024-10-08 15:03:07.782773+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bim
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.fam
#   internal-id: projects/282373700333/locations/us-central1/operations/10014404981216081780
#   job-id: 1-regenie---jon126--241008-142953-11
#   job-name: 1-regenie-plinkprep
#   labels: {}
#   last-update: '2024-10-08 15:03:08.205847'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241008/142952/1-regenie---jon126--241008-142953-11-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241008/results/21
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 500
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-c1414d29c7d2c02b8ca9083d449684d5
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-a
#     zones: []
#   script: "\n\nset -o pipefail \nset -o errexit\n\nplink     --bed \"${bedfile}\"\
#     \     --bim \"${bimfile}\"     --fam \"${famfile}\"     --threads 3 \\ \n    --geno\
#     \ 0.01     --hwe 1e-15     --indep-pairwise 1000 100 0.8     --write-snplist \
#     \    --memory 14000     --out qc_ldpruned_snps_chr\"${chr}\"\n\nexport output_snplist=\"\
#     qc_ldpruned_snps_chr${chr}.snplist\" \nexport output_ldprune_in=\"qc_ldpruned_snps_chr${chr}.prune.in\"\
#     \ \nexport output_ldprune_out=\"qc_ldpruned_snps_chr${chr}.prune.out\"\n\nmv ${output_snplist}\
#     \ ${output_ldprune_in} ${output_ldprune_out} -t ${OUTPUT_PATH}\n"
#   script-name: 1_regenie_plinkprep.sh
#   start-time: '2024-10-08 14:30:01.229213'
#   status: FAILURE
#   status-detail: |
#     Error: --threads only accepts 1 parameter.
#     For more information, try "plink --help <flag name>" or "plink --help | more".
#   status-message: |-
#     Stopped running "user-command": exit status 5: Error: --threads only accepts 1 parameter.
#     For more information, try "plink --help <flag name>" or "plink --help | more".
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8

# %%
#Look at log file
# !gsutil cp gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241008/150958/1-regenie---jon126--241008-150959-63-task-None.log ./
# Out:
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/1-regenie-plinkprep/jon126/20241008/150958/1-regenie---jon126--241008-150959-63-task-None.log...
# / [1 files][ 77.2 KiB/ 77.2 KiB]
# Operation completed over 1 objects/77.2 KiB.

# %%
#Cancel running jobs
# !ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --jobs '*' --users 'jon126' --location us-central1
# Out:
# Delete running jobs:
#   user:
#     {'jon126'}
#
#   job-id:
#     ['*']
#
# Found 20 tasks to delete.
# 20 jobs deleted

# %%
#Move all the plinkprep output folders to the same parent folder in gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/

# !gsutil -m mv -r gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241008/* gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/
# !gsutil -m mv -r gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/* gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/
# !gsutil -m mv -r gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/* gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/
# Out:
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/10/qc_ldpruned_snps_chr10.prune.in [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/10/qc_ldpruned_snps_chr10.prune.out [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/10/qc_ldpruned_snps_chr10.snplist [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/17/qc_ldpruned_snps_chr17.prune.in [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/17/qc_ldpruned_snps_chr17.prune.out [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/17/qc_ldpruned_snps_chr17.snplist [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/5/qc_ldpruned_snps_chr5.prune.in [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/5/qc_ldpruned_snps_chr5.prune.out [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/5/qc_ldpruned_snps_chr5.snplist [Content-Type=application/octet-stream]...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/10/qc_ldpruned_snps_chr10.prune.out...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/10/qc_ldpruned_snps_chr10.prune.in...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/10/qc_ldpruned_snps_chr10.snplist...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/17/qc_ldpruned_snps_chr17.snplist...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/17/qc_ldpruned_snps_chr17.prune.in...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/17/qc_ldpruned_snps_chr17.prune.out...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/5/qc_ldpruned_snps_chr5.prune.in...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/5/qc_ldpruned_snps_chr5.prune.out...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241009/results/5/qc_ldpruned_snps_chr5.snplist...
# / [9/9 files][264.1 MiB/264.1 MiB] 100% Done
# Operation completed over 9 objects/264.1 MiB.
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/results/12/qc_ldpruned_snps_chr12.prune.in [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/results/12/qc_ldpruned_snps_chr12.prune.out [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/results/8/qc_ldpruned_snps_chr8.snplist [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/results/12/qc_ldpruned_snps_chr12.snplist [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/results/8/qc_ldpruned_snps_chr8.prune.in [Content-Type=application/octet-stream]...
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/results/8/qc_ldpruned_snps_chr8.prune.out [Content-Type=application/octet-stream]...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/results/12/qc_ldpruned_snps_chr12.prune.in...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/results/12/qc_ldpruned_snps_chr12.snplist...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/results/12/qc_ldpruned_snps_chr12.prune.out...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/results/8/qc_ldpruned_snps_chr8.prune.in...
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/results/8/qc_ldpruned_snps_chr8.prune.out...
# / [6/6 files][191.3 MiB/191.3 MiB] 100% Done
# Operation completed over 6 objects/191.3 MiB.
# Removing gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/20241010/results/8/qc_ldpruned_snps_chr8.snplist...

# %%
#Evaluate the prune.in file from plinkprep step

# !gsutil cp gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/21/qc_ldpruned_snps_chr21.prune.in ./
# Out:
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/21/qc_ldpruned_snps_chr21.prune.in...
# / [1 files][  9.4 MiB/  9.4 MiB]
# Operation completed over 1 objects/9.4 MiB.

# %% [markdown]
# ## 1.1b Plinkprep2 Step
#
# This details how you need to extract a follow-up snplist that uses to filter only for LDpruned variants which have a minMAC of 50 in the individuals with non-NA value for that phenotype.
#
# 50/10000 translates to about ~0.5% MAF so reasonable filter.

# %%
## MODIFY FOR FULL DATA RUN 
JOB_NAME='plinkprep2'
PHENOTYPE='NTproBNP'
PHENO_FILEPATH="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_pheno.tsv"

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env JOB_NAME={JOB_NAME}
# %env PHENOTYPE={PHENOTYPE}
# %env PHENO_FILEPATH={PHENO_FILEPATH}
# Out:
# env: JOB_NAME=plinkprep2
# env: PHENOTYPE=NTproBNP
# env: PHENO_FILEPATH=gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_pheno.tsv

# %%
## Analysis Results Folder 
line_count_results_folder = os.path.join(
    os.getenv('WORKSPACE_BUCKET'),
    'dsub',
    'results',
    JOB_NAME,
    PHENOTYPE,
    USER_NAME,
    datetime.now().strftime('%Y%m%d'))

line_count_results_folder

## Where the output files will go
output_files = os.path.join(line_count_results_folder, "results")
print(output_files)

OUTPUT_FILES = output_files

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env OUTPUT_FILES={OUTPUT_FILES}
# Out:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/plinkprep2/NTproBNP/jon126/20241022/results
# env: OUTPUT_FILES=gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/plinkprep2/NTproBNP/jon126/20241022/results

# %%
#This is the plink preparatory in REGENIE 
filename='1_regenie_plinkprep2.sh'

script = '''
set -o pipefail 
set -o errexit

awk -v var="${pheno}" -F'\t' 'NR==1 {for (i=1; i<=NF; i++) if ($i == var) col=i} NR > 1 && $col != "NA" {print $1, $2}' "${pheno_file}" > nonNA_plinkids.txt

plink \
    --bed "${bedfile}" \
    --bim "${bimfile}" \
    --fam "${famfile}" \
    --keep nonNA_plinkids.txt \
    --extract "${step1_snplist}" \
    --write-snplist \
    --mac 50 \
    --memory 14000 \
    --out "${pheno}"_qc_ldpruned_MAC50filtered_chr"${chr}"

export output_snplist="${pheno}_qc_ldpruned_MAC50filtered_chr${chr}.snplist"
mv ${output_snplist} -t ${OUTPUT_PATH}
'''

with open(filename,'w') as fp:
    fp.write(script)

#Upload to GCP Bucket
# !gsutil cp ./1_regenie_plinkprep2.sh {my_bucket}/dsub/scripts/
# Out:
# Copying file://./1_regenie_plinkprep2.sh [Content-Type=text/x-sh]...
# / [1 files][  557.0 B/  557.0 B]
# Operation completed over 1 objects/557.0 B.

# %%
# %%bash --out LINE_COUNT_JOB_ID
# #This submits the job btw for each chromosome!
#
# # Get a shorter username to leave more characters for the job name.
# DSUB_USER_NAME="$(echo "${OWNER_EMAIL}" | cut -d@ -f1)"
#
# # For AoU RWB projects network name is "network".
# AOU_NETWORK=network
# AOU_SUBNETWORK=subnetwork
#
# MACHINE_TYPE="n2-standard-4"
# BASH_SCRIPT="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/1_regenie_plinkprep2.sh" #From above command
#
# # Python is 'right side limited' wherein the last value is not included
# # To run the regression across all chromosomes, set lower to 1 and upper to 23
# # To run across one chromosome, set lower to the chomosome-of-interest and upper to the following
#
# # LOWER=1
# # UPPER=23
#
# #Test on 1 chromosome first
# LOWER=1
# UPPER=23
# for ((chromo=$LOWER;chromo<$UPPER;chromo+=1))
# do
#     dsub \
#     --provider google-cls-v2 \
#     --user-project "${GOOGLE_PROJECT}" \
#     --project "${GOOGLE_PROJECT}" \
#     --image "us.gcr.io/broad-dsp-gcr-public/terra-jupyter-aou:2.2.14" \
#     --network "${AOU_NETWORK}" \
#     --subnetwork "${AOU_SUBNETWORK}" \
#     --service-account "$(gcloud config get-value account)" \
#     --user "${DSUB_USER_NAME}" \
#     --regions us-central1 \
#     --logging "${WORKSPACE_BUCKET}/dsub/logs/{job-name}/{user-id}/$(date +'%Y%m%d/%H%M%S')/{job-id}-{task-id}-{task-attempt}.log" \
#     "$@" \
#     --preemptible \
#     --disk-size 1000 \
#     --boot-disk-size 100 \
#     --machine-type ${MACHINE_TYPE} \
#     --name "${JOB_NAME}" \
#     --script "${BASH_SCRIPT}" \
#     --env GOOGLE_PROJECT=${GOOGLE_PROJECT} \
#     --input bedfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.bed" \
#     --input bimfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.bim" \
#     --input famfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.fam" \
#     --input step1_snplist="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/${chromo}/qc_ldpruned_snps_chr${chromo}.prune.in" \
#     --input pheno_file="${PHENO_FILEPATH}" \
#     --env chr=${chromo} \
#     --env pheno=${PHENOTYPE} \
#     --output-recursive OUTPUT_PATH="${OUTPUT_FILES}"
# done
#
# #N.B Make sure there are no spaces after the \ otherwise the dsub script breaks
# Out:
# Job properties:
#   job-id: plinkprep2--jon126--241022-154010-03
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/5677982850354247549
# Launched job-id: plinkprep2--jon126--241022-154010-03
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154010-03' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154010-03' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154012-15
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/10068118253030462636
# Launched job-id: plinkprep2--jon126--241022-154012-15
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154012-15' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154012-15' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154014-11
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/13224856384460309786
# Launched job-id: plinkprep2--jon126--241022-154014-11
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154014-11' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154014-11' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154016-10
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/107721072188935433
# Launched job-id: plinkprep2--jon126--241022-154016-10
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154016-10' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154016-10' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154018-04
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/873971644923994608
# Launched job-id: plinkprep2--jon126--241022-154018-04
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154018-04' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154018-04' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154019-97
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/7310004481157278328
# Launched job-id: plinkprep2--jon126--241022-154019-97
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154019-97' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154019-97' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154021-85
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/16398491089015431497
# Launched job-id: plinkprep2--jon126--241022-154021-85
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154021-85' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154021-85' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154023-74
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/2918132110647279321
# Launched job-id: plinkprep2--jon126--241022-154023-74
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154023-74' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154023-74' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154025-66
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/5382476792043139516
# Launched job-id: plinkprep2--jon126--241022-154025-66
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154025-66' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154025-66' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154027-60
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/13976784104012700182
# Launched job-id: plinkprep2--jon126--241022-154027-60
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154027-60' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154027-60' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154029-50
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/15539537902422049082
# Launched job-id: plinkprep2--jon126--241022-154029-50
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154029-50' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154029-50' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154031-43
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/4452304342888228183
# Launched job-id: plinkprep2--jon126--241022-154031-43
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154031-43' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154031-43' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154033-33
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/13728909996707854486
# Launched job-id: plinkprep2--jon126--241022-154033-33
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154033-33' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154033-33' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154035-23
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/12048609031682186669
# Launched job-id: plinkprep2--jon126--241022-154035-23
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154035-23' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154035-23' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154037-18
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/8714214184404422503
# Launched job-id: plinkprep2--jon126--241022-154037-18
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154037-18' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154037-18' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154039-12
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/9463629244407741066
# Launched job-id: plinkprep2--jon126--241022-154039-12
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154039-12' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154039-12' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154041-08
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/13025695115117778472
# Launched job-id: plinkprep2--jon126--241022-154041-08
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154041-08' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154041-08' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154043-03
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/9208486417681737859
# Launched job-id: plinkprep2--jon126--241022-154043-03
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154043-03' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154043-03' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154044-94
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/9512174892181843950
# Launched job-id: plinkprep2--jon126--241022-154044-94
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154044-94' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154044-94' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154046-83
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/9750137628935411988
# Launched job-id: plinkprep2--jon126--241022-154046-83
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154046-83' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154046-83' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154048-75
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/12035335773764050845
# Launched job-id: plinkprep2--jon126--241022-154048-75
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154048-75' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154048-75' --users 'jon126'
# Job properties:
#   job-id: plinkprep2--jon126--241022-154050-63
#   job-name: plinkprep2
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/3544802086698139777
# Launched job-id: plinkprep2--jon126--241022-154050-63
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154050-63' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'plinkprep2--jon126--241022-154050-63' --users 'jon126'

# %%
# Check the status of your job submissions
# !dstat \
    --provider google-cls-v2 \
    --project terra-vpc-sc-4e1b6fe8 \
    --location us-central1 \
    --jobs '*' \
    --users 'jon126' \
    --status '*' \
    --age 1d
# Out:
# Job Name         Status                                      Last Update
# ---------------  ------------------------------------------  --------------
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:24
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:24
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:30
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:27
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:47
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:26
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:13
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:13
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:15
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:24
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:12
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:09
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:11
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:10
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:40:58
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:14
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:00
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:40:58
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:40:56
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:41:02
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:40:59
# plinkprep2       Pulling "us.gcr.io/broad-dsp-gcr-public...  10-22 15:40:56
# plinkprep2       Success                                     10-22 15:20:00
# plinkprep2       The operation was cancelled                 10-22 14:33:16
# regenie-ntpr...  Stopped running "user-command": exit st...  10-21 17:49:21
# regenie-ntpr...  Stopped running "user-command": exit st...  10-21 16:37:43

# %%
# Check the status of your job submissions
# !dstat \
    --provider google-cls-v2 \
    --project terra-vpc-sc-4e1b6fe8 \
    --location us-central1 \
    --jobs '*' \
    --users 'jon126' \
    --status 'SUCCESS' \
    --full \
    --age 1d
# Out:
# - create-time: '2024-10-22 14:35:28.001853'
#   dsub-version: v0-5-0
#   end-time: '2024-10-22 15:20:00.342526'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chrom: '21'
#     pheno: NTproBNP
#   events:
#   - name: start
#     start-time: 2024-10-22 14:35:40.001515+00:00
#   - name: pulling-image
#     start-time: 2024-10-22 14:36:18.962501+00:00
#   - name: localizing-files
#     start-time: 2024-10-22 14:51:45.029876+00:00
#   - name: running-docker
#     start-time: 2024-10-22 15:13:39.643414+00:00
#   - name: delocalizing-files
#     start-time: 2024-10-22 15:19:55.774982+00:00
#   - name: ok
#     start-time: 2024-10-22 15:20:00.342526+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bim
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.fam
#     pheno_file: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_pheno.tsv
#     step1_snplist: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/21/qc_ldpruned_snps_chr21.prune.in
#   internal-id: projects/282373700333/locations/us-central1/operations/7988324675532233438
#   job-id: plinkprep2--jon126--241022-143527-86
#   job-name: plinkprep2
#   labels: {}
#   last-update: '2024-10-22 15:20:00.342526'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/plinkprep2/jon126/20241022/143526/plinkprep2--jon126--241022-143527-86-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/plinkprep2/NTproBNP/jon126/20241022/results
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 100
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-fb1da48ad76783df0c53308db5eaeae3
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-b
#     zones: []
#   script: "\nset -o pipefail \nset -o errexit\n\nawk -v var=\"${pheno}\" -F'\t' 'NR==1\
#     \ {for (i=1; i<=NF; i++) if ($i == var) col=i} NR > 1 && $col != \"NA\" {print\
#     \ $1, $2}' \"${pheno_file}\" > nonNA_plinkids.txt\n\nplink     --bed \"${bedfile}\"\
#     \     --bim \"${bimfile}\"     --fam \"${famfile}\"     --keep nonNA_plinkids.txt\
#     \     --extract \"${step1_snplist}\"     --write-snplist     --mac 50     --memory\
#     \ 14000     --out \"${pheno}\"_qc_ldpruned_MAC50filtered_chr\"${chr}\"\n\nexport\
#     \ output_snplist=\"${pheno}_qc_ldpruned_MAC50filtered_chr${chr}.snplist\"\nmv\
#     \ ${output_snplist} -t ${OUTPUT_PATH}\n"
#   script-name: 1_regenie_plinkprep2.sh
#   start-time: '2024-10-22 14:35:40.001515'
#   status: SUCCESS
#   status-detail: Success
#   status-message: Success
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8

# %%
# !gsutil cp gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/plinkprep2/jon126/20241022/143526/plinkprep2--jon126--241022-143527-86-task-None.log ./
# Out:
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/plinkprep2/jon126/20241022/143526/plinkprep2--jon126--241022-143527-86-task-None.log...
# / [1 files][ 16.1 KiB/ 16.1 KiB]
# Operation completed over 1 objects/16.1 KiB.

# %%
#Cancel running jobs
# !ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --jobs '*' --users 'jon126' --location us-central1
# Out:
# Delete running jobs:
#   user:
#     {'jon126'}
#
#   job-id:
#     ['*']
#
# Found 1 tasks to delete.
# 1 job deleted

# %%
# !gsutil ls gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/plinkprep2/NTproBNP/jon126/20241022/results
# Out:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/plinkprep2/NTproBNP/jon126/20241022/results/NTproBNP_qc_ldpruned_MAC50filtered_chr.snplist
# CommandException: "rm" command does not support "file://" URLs. Did you mean to use a gs:// URL?

# %% [markdown]
# ## 1.2 REGENIE HCM GWAS Step

# %%
## MODIFY FOR FULL DATA RUN 
JOB_NAME='REGENIE_hcm'
PHENOTYPE='hcm'
TRAIT_TYPE='cc'
PHENO_FILEPATH="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/hcm_regenie_pheno.tsv"
COV_FILEPATH="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/hcm_regenie_cov.tsv"

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env JOB_NAME={JOB_NAME}
# %env PHENOTYPE={PHENOTYPE}
# %env TRAIT_TYPE={TRAIT_TYPE}
# %env PHENO_FILEPATH={PHENO_FILEPATH}
# %env COV_FILEPATH={COV_FILEPATH}
# Out:
# env: JOB_NAME=REGENIE_hcm
# env: PHENOTYPE=hcm
# env: TRAIT_TYPE=cc
# env: PHENO_FILEPATH=gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/hcm_regenie_pheno.tsv
# env: COV_FILEPATH=gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/hcm_regenie_cov.tsv

# %%
#Check the pheno and covar files

# !gsutil cp 'gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/hcm_regenie_pheno.tsv' ./
# !gsutil cp 'gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/hcm_regenie_cov.tsv' ./
# Out:
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/hcm_regenie_pheno.tsv...
# / [1 files][  5.2 MiB/  5.2 MiB]
# Operation completed over 1 objects/5.2 MiB.
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/hcm_regenie_cov.tsv...
# \ [1 files][ 62.9 MiB/ 62.9 MiB]
# Operation completed over 1 objects/62.9 MiB.

# %%
## Analysis Results Folder 
line_count_results_folder = os.path.join(
    os.getenv('WORKSPACE_BUCKET'),
    'dsub',
    'results',
    JOB_NAME,
    USER_NAME,
    datetime.now().strftime('%Y%m%d'))

line_count_results_folder
# Out:
# 'gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_hcm/jon126/20241021'

# %%
## Where the output files will go
output_files = os.path.join(line_count_results_folder, "results")
print(output_files)

OUTPUT_FILES = output_files

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env OUTPUT_FILES={OUTPUT_FILES}
# Out:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_hcm/jon126/20241021/results
# env: OUTPUT_FILES=gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_hcm/jon126/20241021/results

# %%
#This is the actual REGENIE bash script
#Note that we assume no filtering of variants in the REGENIE script because we assume that the acaf_threshold nature of it has filtered the variants.
filename2='2_regenie_aous_hcm.sh'

script = '''
set -o pipefail 
set -o errexit

#This defines the actual bed_prefix, assuming localisation of the input bed/bim/fam files

echo "${bedfile}"
echo "${bimfile}"
echo "${famfile}"

bed_prefix=/mnt/data/input/gs/fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr"${chrom}" 

regenie \
    --step 1 \
    --bed "${bed_prefix}" \
    --phenoFile "${pheno_file}" \
    --phenoCol "${pheno}" \
    --covarFile "${cov_file}" \
    --catCovarList sex \
    --covarColList "age,ht,wt,pc1,pc2,pc3,pc4,pc5,pc6,pc7,pc8,pc9,pc10" \
    --bsize 1000 \
    --minMAC 50 \
    --extract "${step1_snplist}" \
    --verbose \
    --"${trait}" \ 
    --ref-first \
    --out "${pheno}"_step1_chr"${chrom}"

#regenie pt 2
regenie \
    --step 2 \
    --bed "${bed_prefix}" \
    --phenoFile "${pheno_file}" \
    --phenoCol "${pheno}" \
    --covarFile "${cov_file}" \
    --catCovarList sex \
    --covarColList "age,ht,wt,pc1,pc2,pc3,pc4,pc5,pc6,pc7,pc8,pc9,pc10" \
    --pred "${pheno}"_step1_chr"${chrom}"_pred.list \
    --bsize 1000 \
    --minMAC 50 \
    --verbose \
    --"${trait}" \
    --ref-first \
    --out "${pheno}"_step2_chr"${chrom}"

export regenie_results=${pheno}_step2_chr"{chrom}".regenie
mv ${regenie_results} -t ${OUTPUT_PATH}
'''

with open(filename2,'w') as fp:
    fp.write(script)

# %%
#Upload to GCP Bucket
# !gsutil cp ./2_regenie_aous_hcm.sh {my_bucket}/dsub/scripts/
# Out:
# Copying file://./2_regenie_aous_hcm.sh [Content-Type=text/x-sh]...
# / [1 files][  1.2 KiB/  1.2 KiB]
# Operation completed over 1 objects/1.2 KiB.

# %%
#Check the files are there
# !gsutil ls {my_bucket}/dsub/scripts/*.sh

# %%
# %%bash --out LINE_COUNT_JOB_ID
# #This submits the job btw for each chromosome!
#
# # Get a shorter username to leave more characters for the job name.
# DSUB_USER_NAME="$(echo "${OWNER_EMAIL}" | cut -d@ -f1)"
#
# # For AoU RWB projects network name is "network".
# AOU_NETWORK=network
# AOU_SUBNETWORK=subnetwork
#
# MACHINE_TYPE="n2-standard-4"
# BASH_SCRIPT="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/2_regenie_aous_hcm.sh" #From above command
#
# # Python is 'right side limited' wherein the last value is not included
# # To run the regression across all chromosomes, set lower to 1 and upper to 23
# # To run across one chromosome, set lower to the chomosome-of-interest and upper to the following
#
# # LOWER=1
# # UPPER=23
#
# #Test on 1 chromosome first
# LOWER=21
# UPPER=22
# for ((chromo=$LOWER;chromo<$UPPER;chromo+=1))
# do
#     dsub \
#     --provider google-cls-v2 \
#     --user-project "${GOOGLE_PROJECT}" \
#     --project "${GOOGLE_PROJECT}" \
#     --image "${ARTIFACT_REGISTRY_DOCKER_REPO}/skoyamamd/regenie_3.4.1:latest" \
#     --network "${AOU_NETWORK}" \
#     --subnetwork "${AOU_SUBNETWORK}" \
#     --service-account "$(gcloud config get-value account)" \
#     --user "${DSUB_USER_NAME}" \
#     --regions us-central1 \
#     --logging "${WORKSPACE_BUCKET}/dsub/logs/{job-name}/{user-id}/$(date +'%Y%m%d/%H%M%S')/{job-id}-{task-id}-{task-attempt}.log" \
#     "$@" \
#     --preemptible \
#     --disk-size 1000 \
#     --boot-disk-size 100 \
#     --machine-type ${MACHINE_TYPE} \
#     --name "${JOB_NAME}" \
#     --script "${BASH_SCRIPT}" \
#     --env GOOGLE_PROJECT=${GOOGLE_PROJECT} \
#     --input bedfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.bed" \
#     --input bimfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.bim" \
#     --input famfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.fam" \
#     --input pheno_file="${PHENO_FILEPATH}" \
#     --input cov_file="${COV_FILEPATH}" \
#     --input step1_snplist="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/${chromo}/qc_ldpruned_snps_chr${chromo}.prune.in" \
#     --env trait=${TRAIT_TYPE} \
#     --env chrom=${chromo} \
#     --env pheno=${PHENOTYPE} \
#     --output-recursive OUTPUT_PATH="${OUTPUT_FILES}/${chromo}"
# done
#
# #N.B Make sure there are no spaces after the \ otherwise the dsub script breaks

# %% [markdown]
# ## REGENIE  PP GWAS Step

# %% [markdown]
# ### DSub Parameter Setting
#
# This requires modification for each different phenotype you run.

# %%
## MODIFY FOR FULL DATA RUN 
JOB_NAME='REGENIE_ntprobnp'
PHENOTYPE='NTproBNP' #NTproBNP or NPPB or TNNI3 or TNNT2
TRAIT_TYPE='qt'
PHENO_FILEPATH="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_pheno.tsv"
COV_FILEPATH="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_cov.tsv"

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env JOB_NAME={JOB_NAME}
# %env PHENOTYPE={PHENOTYPE}
# %env TRAIT_TYPE={TRAIT_TYPE}
# %env PHENO_FILEPATH={PHENO_FILEPATH}
# %env COV_FILEPATH={COV_FILEPATH}
# Out:
# env: JOB_NAME=REGENIE_ntprobnp
# env: PHENOTYPE=NTproBNP
# env: TRAIT_TYPE=qt
# env: PHENO_FILEPATH=gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_pheno.tsv
# env: COV_FILEPATH=gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_cov.tsv

# %%
#Check the .fam file to get the correct FID and IID format 

# !gsutil -u $GOOGLE_PROJECT cp gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.fam ./

# !gsutil cp gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_pheno.tsv ./
# !gsutil cp gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_cov.tsv ./
# Out:
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_cov.tsv...
# - [1 files][ 59.3 MiB/ 59.3 MiB]
# Operation completed over 1 objects/59.3 MiB.

# %%
## Analysis Results Folder 
line_count_results_folder = os.path.join(
    os.getenv('WORKSPACE_BUCKET'),
    'dsub',
    'results',
    JOB_NAME,
    USER_NAME,
    datetime.now().strftime('%Y%m%d'))

line_count_results_folder
# Out:
# 'gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_ntprobnp/jon126/20241021'

# %%
## Where the output files will go
output_files = os.path.join(line_count_results_folder, "results")
print(output_files)

OUTPUT_FILES = output_files

# Save this Python variable as an environment variable so that its easier to use within %%bash cells.
# %env OUTPUT_FILES={OUTPUT_FILES}
# Out:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_ntprobnp/jon126/20241021/results
# env: OUTPUT_FILES=gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_ntprobnp/jon126/20241021/results

# %% [markdown]
# ### REGENIE Bash Script
#
# This details and writes out a .sh script in the local Jupyter disk and then uploads it to GCP Bucket in order for dsub to run it.

# %%
#This is the actual REGENIE bash script
filename2='2_regenie_aous_pp.sh'

script = '''
set -o pipefail 
set -o errexit

#This defines the actual bed_prefix, assuming localisation of the input bed/bim/fam files

echo "${bedfile}"
echo "${bimfile}"
echo "${famfile}"

bed_prefix=/mnt/data/input/gs/fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr"${chrom}" 

regenie \
    --step 1 \
    --bed "${bed_prefix}" \
    --phenoFile "${pheno_file}" \
    --phenoCol "${pheno}" \
    --covarFile "${cov_file}" \
    --catCovarList "sex" \
    --covarColList "ht,wt,pc1,pc2,pc3,pc4,pc5,pc6,pc7,pc8,pc9,pc10,age_${pheno}" \
    --bsize 1000 \
    --minMAC 50 \
    --extract "${step1_snplist}" \
    --verbose \
    --"${trait}" \
    --apply-rint \
    --ref-first \
    --out "${pheno}"_step1_chr"${chrom}"

#regenie pt 2
regenie \
    --step 2 \
    --bed "${bed_prefix}" \
    --phenoFile "${pheno_file}" \
    --phenoCol "${pheno}" \
    --covarFile "${cov_file}" \
    --catCovarList "sex" \
    --covarColList "ht,wt,pc1,pc2,pc3,pc4,pc5,pc6,pc7,pc8,pc9,pc10,age_${pheno}" \
    --pred "${pheno}"_step1_chr"${chrom}"_pred.list \
    --bsize 1000 \
    --minMAC 50 \
    --verbose \
    --"${trait}" \
    --apply-rint \
    --ref-first \
    --out "${pheno}"_step2_chr"${chrom}"

export regenie_results="${pheno}"step2_chr"{chrom}".regenie
mv ${regenie_results} -t ${OUTPUT_PATH}
'''

with open(filename2,'w') as fp:
    fp.write(script)

# %%
#Upload to GCP Bucket
# !gsutil cp ./2_regenie_aous_pp.sh {my_bucket}/dsub/scripts/
# Out:
# Copying file://./2_regenie_aous_pp.sh [Content-Type=text/x-sh]...
# / [1 files][  1.2 KiB/  1.2 KiB]
# Operation completed over 1 objects/1.2 KiB.

# %%
#Check the script files are there
# !gsutil ls {my_bucket}/dsub/scripts/*.sh
# Out:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/1_regenie_plinkprep.sh
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/2_regenie_aous_pp.sh

# %%
#Check for the input files
# !gsutil ls {my_bucket}/PP/DATA/*.tsv

# %%
#Check for the ldpruned snplist files
# !gsutil ls -r {my_bucket}/dsub/results/1_regenie_plinkprep/jon126/results/
# Out:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/:
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/1/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/1/qc_ldpruned_snps_chr1.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/1/qc_ldpruned_snps_chr1.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/1/qc_ldpruned_snps_chr1.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/10/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/10/qc_ldpruned_snps_chr10.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/10/qc_ldpruned_snps_chr10.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/10/qc_ldpruned_snps_chr10.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/11/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/11/qc_ldpruned_snps_chr11.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/11/qc_ldpruned_snps_chr11.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/11/qc_ldpruned_snps_chr11.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/12/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/12/qc_ldpruned_snps_chr12.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/12/qc_ldpruned_snps_chr12.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/12/qc_ldpruned_snps_chr12.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/13/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/13/qc_ldpruned_snps_chr13.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/13/qc_ldpruned_snps_chr13.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/13/qc_ldpruned_snps_chr13.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/14/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/14/qc_ldpruned_snps_chr14.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/14/qc_ldpruned_snps_chr14.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/14/qc_ldpruned_snps_chr14.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/15/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/15/qc_ldpruned_snps_chr15.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/15/qc_ldpruned_snps_chr15.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/15/qc_ldpruned_snps_chr15.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/16/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/16/qc_ldpruned_snps_chr16.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/16/qc_ldpruned_snps_chr16.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/16/qc_ldpruned_snps_chr16.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/17/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/17/qc_ldpruned_snps_chr17.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/17/qc_ldpruned_snps_chr17.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/17/qc_ldpruned_snps_chr17.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/18/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/18/qc_ldpruned_snps_chr18.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/18/qc_ldpruned_snps_chr18.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/18/qc_ldpruned_snps_chr18.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/19/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/19/qc_ldpruned_snps_chr19.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/19/qc_ldpruned_snps_chr19.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/19/qc_ldpruned_snps_chr19.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/2/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/2/qc_ldpruned_snps_chr2.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/2/qc_ldpruned_snps_chr2.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/2/qc_ldpruned_snps_chr2.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/20/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/20/qc_ldpruned_snps_chr20.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/20/qc_ldpruned_snps_chr20.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/20/qc_ldpruned_snps_chr20.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/21/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/21/qc_ldpruned_snps_chr21.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/21/qc_ldpruned_snps_chr21.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/21/qc_ldpruned_snps_chr21.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/22/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/22/qc_ldpruned_snps_chr22.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/22/qc_ldpruned_snps_chr22.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/22/qc_ldpruned_snps_chr22.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/3/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/3/qc_ldpruned_snps_chr3.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/3/qc_ldpruned_snps_chr3.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/3/qc_ldpruned_snps_chr3.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/4/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/4/qc_ldpruned_snps_chr4.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/4/qc_ldpruned_snps_chr4.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/4/qc_ldpruned_snps_chr4.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/5/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/5/qc_ldpruned_snps_chr5.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/5/qc_ldpruned_snps_chr5.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/5/qc_ldpruned_snps_chr5.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/6/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/6/qc_ldpruned_snps_chr6.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/6/qc_ldpruned_snps_chr6.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/6/qc_ldpruned_snps_chr6.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/7/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/7/qc_ldpruned_snps_chr7.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/7/qc_ldpruned_snps_chr7.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/7/qc_ldpruned_snps_chr7.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/8/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/8/qc_ldpruned_snps_chr8.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/8/qc_ldpruned_snps_chr8.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/8/qc_ldpruned_snps_chr8.snplist
#
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/9/:
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/9/qc_ldpruned_snps_chr9.prune.in
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/9/qc_ldpruned_snps_chr9.prune.out
# gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/9/qc_ldpruned_snps_chr9.snplist

# %% [markdown]
# ### Dsub Submission Script for REGENIE
#
# Note that all `--input` files have to be in double quotations
# whereas all `--env` environmental variables (for dsub) are NOT in quotations e.g `--env chrom=${chromo}` so if you need to use a Bash environmental variable for `--env` (in dsub) you remove the double quotes e.g `--env GOOGLE_PROJECT=${GOOGLE_PROJECT}`
#
# Bash environmental variables are in `"${...}"` format

# %%
# !echo "${ARTIFACT_REGISTRY_DOCKER_REPO}" #Base location for public Docker images via Dockerhub
# Out:
# us-central1-docker.pkg.dev/all-of-us-rw-prod/aou-rw-gar-remote-repo-docker-prod

# %%
# %%bash --out LINE_COUNT_JOB_ID
# #This submits the job btw for each chromosome!
#
# # Get a shorter username to leave more characters for the job name.
# DSUB_USER_NAME="$(echo "${OWNER_EMAIL}" | cut -d@ -f1)"
#
# # For AoU RWB projects network name is "network".
# AOU_NETWORK=network
# AOU_SUBNETWORK=subnetwork
#
# MACHINE_TYPE="n2-standard-4"
# BASH_SCRIPT="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/scripts/2_regenie_aous_pp.sh" #From above command
#
# # Python is 'right side limited' wherein the last value is not included
# # To run the regression across all chromosomes, set lower to 1 and upper to 23
# # To run across one chromosome, set lower to the chomosome-of-interest and upper to the following
#
# # LOWER=1
# # UPPER=23
#
# #Test on 1 chromosome first
# LOWER=21
# UPPER=22
# for ((chromo=$LOWER;chromo<$UPPER;chromo+=1))
# do
#     dsub \
#     --provider google-cls-v2 \
#     --user-project "${GOOGLE_PROJECT}" \
#     --project "${GOOGLE_PROJECT}" \
#     --image "${ARTIFACT_REGISTRY_DOCKER_REPO}/skoyamamd/regenie_3.4.1:latest" \
#     --network "${AOU_NETWORK}" \
#     --subnetwork "${AOU_SUBNETWORK}" \
#     --service-account "$(gcloud config get-value account)" \
#     --user "${DSUB_USER_NAME}" \
#     --regions us-central1 \
#     --logging "${WORKSPACE_BUCKET}/dsub/logs/{job-name}/{user-id}/$(date +'%Y%m%d/%H%M%S')/{job-id}-{task-id}-{task-attempt}.log" \
#     "$@" \
#     --preemptible \
#     --disk-size 1000 \
#     --boot-disk-size 100 \
#     --machine-type ${MACHINE_TYPE} \
#     --name "${JOB_NAME}" \
#     --script "${BASH_SCRIPT}" \
#     --env GOOGLE_PROJECT=${GOOGLE_PROJECT} \
#     --input bedfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.bed" \
#     --input bimfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.bim" \
#     --input famfile="gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr${chromo}.fam" \
#     --input pheno_file="${PHENO_FILEPATH}" \
#     --input cov_file="${COV_FILEPATH}" \
#     --input step1_snplist="gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/${chromo}/qc_ldpruned_snps_chr${chromo}.prune.in" \
#     --env trait=${TRAIT_TYPE} \
#     --env chrom=${chromo} \
#     --env pheno=${PHENOTYPE} \
#     --output-recursive OUTPUT_PATH="${OUTPUT_FILES}/${chromo}"
# done
#
# #N.B Make sure there are no spaces after the \ otherwise the dsub script breaks
# Out:
# Job properties:
#   job-id: regenie-nt--jon126--241021-172244-27
#   job-name: regenie-ntprobnp
#   user-id: jon126
# Provider internal-id (operation): projects/282373700333/locations/us-central1/operations/1260923833003924352
# Launched job-id: regenie-nt--jon126--241021-172244-27
# To check the status, run:
#   dstat --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--241021-172244-27' --users 'jon126' --status '*'
# To cancel the job, run:
#   ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --location us-central1 --jobs 'regenie-nt--jon126--241021-172244-27' --users 'jon126'

# %%
# Check the status of your job submissions

# !dstat \
    --provider google-cls-v2 \
    --project terra-vpc-sc-4e1b6fe8 \
    --location us-central1 \
    --jobs '*' \
    --users 'jon126' \
    --status '*' \
    --age 1d
   # --full
# Out:
# Job Name         Status                                      Last Update
# ---------------  ------------------------------------------  --------------
# regenie-ntpr...  Stopped running "user-command": exit st...  10-21 17:49:21
# regenie-ntpr...  Stopped running "user-command": exit st...  10-21 16:37:43
# regenie-ntpr...  Stopped running "user-command": exit st...  10-21 14:49:37
# regenie-ntpr...  Stopped running "user-command": exit st...  10-21 14:14:48
# regenie-ntpr...  Stopped running "user-command": exit st...  10-20 22:17:06

# %%
# Check the status of your job submissions
# !dstat \
    --provider google-cls-v2 \
    --project terra-vpc-sc-4e1b6fe8 \
    --location us-central1 \
    --jobs '*' \
    --users 'jon126' \
    --status 'FAILURE' \
    --full \
    --age 1d
# Out:
# - create-time: '2024-10-21 17:22:44.411188'
#   dsub-version: v0-5-0
#   end-time: '2024-10-21 17:49:21.447291'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chrom: '21'
#     pheno: NTproBNP
#     trait: qt
#   events:
#   - name: start
#     start-time: 2024-10-21 17:22:55.073278+00:00
#   - name: pulling-image
#     start-time: 2024-10-21 17:23:41.082349+00:00
#   - name: localizing-files
#     start-time: 2024-10-21 17:24:21.676255+00:00
#   - name: running-docker
#     start-time: 2024-10-21 17:48:51.181046+00:00
#   - name: fail
#     start-time: 2024-10-21 17:49:18.695973+00:00
#   - name: 'Execution failed: generic::failed_precondition: while running "user-command":
#       unexpected exit status 1 was not ignored'
#     start-time: 2024-10-21 17:49:21.049400+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bim
#     cov_file: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_cov.tsv
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.fam
#     pheno_file: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_pheno.tsv
#     step1_snplist: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/21/qc_ldpruned_snps_chr21.prune.in
#   internal-id: projects/282373700333/locations/us-central1/operations/1260923833003924352
#   job-id: regenie-nt--jon126--241021-172244-27
#   job-name: regenie-ntprobnp
#   labels: {}
#   last-update: '2024-10-21 17:49:21.447291'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/regenie-ntprobnp/jon126/20241021/172243/regenie-nt--jon126--241021-172244-27-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_ntprobnp/jon126/20241021/results/21
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 100
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-bf55c61e8e812e1e7d7a52869cc6dc3b
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-f
#     zones: []
#   script: "\nset -o pipefail \nset -o errexit\n\n#This defines the actual bed_prefix,\
#     \ assuming localisation of the input bed/bim/fam files\n\necho \"${bedfile}\"\n\
#     echo \"${bimfile}\"\necho \"${famfile}\"\n\nbed_prefix=/mnt/data/input/gs/fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr\"\
#     ${chrom}\" \n\nregenie     --step 1     --bed \"${bed_prefix}\"     --phenoFile\
#     \ \"${pheno_file}\"     --phenoCol \"${pheno}\"     --covarFile \"${cov_file}\"\
#     \     --catCovarList \"sex\"     --covarColList \"ht,wt,pc1,pc2,pc3,pc4,pc5,pc6,pc7,pc8,pc9,pc10,age_${pheno}\"\
#     \     --bsize 1000     --minMAC 50     --extract \"${step1_snplist}\"     --verbose\
#     \     --\"${trait}\"     --apply-rint     --ref-first     --out \"${pheno}\"_step1_chr\"\
#     ${chrom}\"\n\n#regenie pt 2\nregenie     --step 2     --bed \"${bed_prefix}\"\
#     \     --phenoFile \"${pheno_file}\"     --phenoCol \"${pheno}\"     --covarFile\
#     \ \"${cov_file}\"     --catCovarList \"sex\"     --covarColList \"ht,wt,pc1,pc2,pc3,pc4,pc5,pc6,pc7,pc8,pc9,pc10,age_${pheno}\"\
#     \     --pred \"${pheno}\"_step1_chr\"${chrom}\"_pred.list     --bsize 1000   \
#     \  --minMAC 50     --verbose     --\"${trait}\"     --apply-rint     --ref-first\
#     \     --out \"${pheno}\"_step2_chr\"${chrom}\"\n\nexport regenie_results=\"${pheno}\"\
#     step2_chr\"{chrom}\".regenie\nmv ${regenie_results} -t ${OUTPUT_PATH}\n"
#   script-name: 2_regenie_aous_pp.sh
#   start-time: '2024-10-21 17:22:55.073278'
#   status: FAILURE
#   status-detail: 'Stopped running "user-command": exit status 1'
#   status-message: 'Stopped running "user-command": exit status 1'
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8
# - create-time: '2024-10-21 16:16:55.719442'
#   dsub-version: v0-5-0
#   end-time: '2024-10-21 16:37:43.580112'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chrom: '21'
#     pheno: NTproBNP
#     trait: qt
#   events:
#   - name: start
#     start-time: 2024-10-21 16:17:06.830256+00:00
#   - name: pulling-image
#     start-time: 2024-10-21 16:17:45.518805+00:00
#   - name: localizing-files
#     start-time: 2024-10-21 16:18:17.148966+00:00
#   - name: running-docker
#     start-time: 2024-10-21 16:37:23.385661+00:00
#   - name: fail
#     start-time: 2024-10-21 16:37:41.469330+00:00
#   - name: 'Execution failed: generic::failed_precondition: while running "user-command":
#       unexpected exit status 1 was not ignored'
#     start-time: 2024-10-21 16:37:43.126401+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bim
#     cov_file: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_cov.tsv
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.fam
#     pheno_file: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_pheno.tsv
#     step1_snplist: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/21/qc_ldpruned_snps_chr21.prune.in
#   internal-id: projects/282373700333/locations/us-central1/operations/11347831396768160243
#   job-id: regenie-nt--jon126--241021-161655-57
#   job-name: regenie-ntprobnp
#   labels: {}
#   last-update: '2024-10-21 16:37:43.580112'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/regenie-ntprobnp/jon126/20241021/161654/regenie-nt--jon126--241021-161655-57-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_ntprobnp/jon126/20241021/results/21
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 100
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-6abbc303995943994670c3177139f532
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-c
#     zones: []
#   script: "\nset -o pipefail \nset -o errexit\n\n#This defines the actual bed_prefix,\
#     \ assuming localisation of the input bed/bim/fam files\n\necho \"${bedfile}\"\n\
#     echo \"${bimfile}\"\necho \"${famfile}\"\n\nbed_prefix=/mnt/data/input/gs/fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr\"\
#     ${chrom}\" \n\nregenie     --step 1     --bed \"${bed_prefix}\"     --phenoFile\
#     \ \"${pheno_file}\"     --phenoCol \"${pheno}\"     --covarFile \"${cov_file}\"\
#     \     --catCovarList \"sex\"     --covarColList \"sex,ht,wt,pc1,pc2,pc3,pc4,pc5,pc6,pc7,pc8,pc9,pc10,age_${pheno}\"\
#     \     --bsize 1000     --extract \"${step1_snplist}\"     --verbose     --\"${trait}\"\
#     \     --apply-rint     --ref-first     --out \"${pheno}\"_step1_chr\"${chrom}\"\
#     \n\n#regenie pt 2\nregenie     --step 2     --bed \"${bed_prefix}\"     --phenoFile\
#     \ \"${pheno_file}\"     --phenoCol \"${pheno}\"     --covarFile \"${cov_file}\"\
#     \     --catCovarList \"sex\"     --covarColList \"sex,ht,wt,pc1,pc2,pc3,pc4,pc5,pc6,pc7,pc8,pc9,pc10,age_${pheno}\"\
#     \     --pred \"${pheno}\"_step1_chr\"${chrom}\"_pred.list     --bsize 1000   \
#     \  --verbose     --\"${trait}\"     --apply-rint     --ref-first     --out \"\
#     ${pheno}\"_step2_chr\"${chrom}\"\n\nexport regenie_results=\"${pheno}\"step2_chr\"\
#     {chrom}\".regenie\nmv ${regenie_results} -t ${OUTPUT_PATH}\n"
#   script-name: 2_regenie_aous_pp.sh
#   start-time: '2024-10-21 16:17:06.830256'
#   status: FAILURE
#   status-detail: 'Stopped running "user-command": exit status 1'
#   status-message: 'Stopped running "user-command": exit status 1'
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8
# - create-time: '2024-10-21 14:25:46.472323'
#   dsub-version: v0-5-0
#   end-time: '2024-10-21 14:49:37.748332'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chrom: '21'
#     pheno: NTproBNP
#     trait: qt
#   events:
#   - name: start
#     start-time: 2024-10-21 14:25:57.761936+00:00
#   - name: pulling-image
#     start-time: 2024-10-21 14:26:35.746595+00:00
#   - name: localizing-files
#     start-time: 2024-10-21 14:27:05.949136+00:00
#   - name: running-docker
#     start-time: 2024-10-21 14:49:26.453299+00:00
#   - name: fail
#     start-time: 2024-10-21 14:49:35.386975+00:00
#   - name: 'Execution failed: generic::failed_precondition: while running "user-command":
#       unexpected exit status 1 was not ignored'
#     start-time: 2024-10-21 14:49:37.399183+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bim
#     cov_file: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_cov.tsv
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.fam
#     pheno_file: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_pheno.tsv
#     step1_snplist: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/21/qc_ldpruned_snps_chr21.prune.in
#   internal-id: projects/282373700333/locations/us-central1/operations/7921659601688075129
#   job-id: regenie-nt--jon126--241021-142546-34
#   job-name: regenie-ntprobnp
#   labels: {}
#   last-update: '2024-10-21 14:49:37.748332'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/regenie-ntprobnp/jon126/20241021/142545/regenie-nt--jon126--241021-142546-34-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_ntprobnp/jon126/20241021/results/21
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 100
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-c3bb6c99b84b31e205e097a0b7358af0
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-f
#     zones: []
#   script: "\nset -o pipefail \nset -o errexit\n\n#This defines the actual bed_prefix,\
#     \ assuming localisation of the input bed/bim/fam files\n\necho \"${bedfile}\"\n\
#     echo \"${bimfile}\"\necho \"${famfile}\"\n\nbed_prefix=/mnt/data/input/gs/fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr\"\
#     ${chrom}\" \n\nregenie     --step 1     --bed \"${bed_prefix}\"     --phenoFile\
#     \ \"${pheno_file}\"     --phenoCol \"${pheno}\"     --covarFile \"${cov_file}\"\
#     \     --catCovarList \"sex\"     --covarColList \"sex, ht, wt, pc1, pc2, pc3,\
#     \ pc4, pc5, pc6, pc7, pc8, pc9, pc10, age_${pheno}\"     --bsize 1000     --extract\
#     \ \"${step1_snplist}\"     --verbose     --\"${trait}\"     --apply-rint     --ref-first\
#     \     --out \"${pheno}\"_step1_chr\"${chrom}\"\n\n#regenie pt 2\nregenie     --step\
#     \ 2     --bed \"${bed_prefix}\"     --phenoFile \"${pheno_file}\"     --phenoCol\
#     \ \"${pheno}\"     --covarFile \"${cov_file}\"     --catCovarList \"sex\"    \
#     \ --covarColList \"sex, ht, wt, pc1, pc2, pc3, pc4, pc5, pc6, pc7, pc8, pc9, pc10,\
#     \ age_${pheno}\"     --pred \"${pheno}\"_step1_chr\"${chrom}\"_pred.list     --bsize\
#     \ 1000     --verbose     --\"${trait}\"     --apply-rint     --ref-first     --out\
#     \ \"${pheno}\"_step2_chr\"${chrom}\"\n\nexport regenie_results=\"${pheno}\"step2_chr\"\
#     {chrom}\".regenie\nmv ${regenie_results} -t ${OUTPUT_PATH}\n"
#   script-name: 2_regenie_aous_pp.sh
#   start-time: '2024-10-21 14:25:57.761936'
#   status: FAILURE
#   status-detail: 'Stopped running "user-command": exit status 1'
#   status-message: 'Stopped running "user-command": exit status 1'
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8
# - create-time: '2024-10-21 13:52:55.231725'
#   dsub-version: v0-5-0
#   end-time: '2024-10-21 14:14:48.759264'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chrom: '21'
#     pheno: NTproBNP
#     trait: qt
#   events:
#   - name: start
#     start-time: 2024-10-21 13:53:05.894116+00:00
#   - name: pulling-image
#     start-time: 2024-10-21 13:54:02.917719+00:00
#   - name: localizing-files
#     start-time: 2024-10-21 13:54:30.097903+00:00
#   - name: running-docker
#     start-time: 2024-10-21 14:14:37.419005+00:00
#   - name: fail
#     start-time: 2024-10-21 14:14:46.476467+00:00
#   - name: 'Execution failed: generic::failed_precondition: while running "user-command":
#       unexpected exit status 1 was not ignored'
#     start-time: 2024-10-21 14:14:48.363931+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bim
#     cov_file: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_cov.tsv
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.fam
#     pheno_file: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_pheno.tsv
#     step1_snplist: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/21/qc_ldpruned_snps_chr21.prune.in
#   internal-id: projects/282373700333/locations/us-central1/operations/2335290077238207194
#   job-id: regenie-nt--jon126--241021-135255-09
#   job-name: regenie-ntprobnp
#   labels: {}
#   last-update: '2024-10-21 14:14:48.759264'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/regenie-ntprobnp/jon126/20241021/135253/regenie-nt--jon126--241021-135255-09-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_ntprobnp/jon126/20241021/results/21
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 100
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-d92ac98ea0b24e2c92b941e52f3f7e4d
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-f
#     zones: []
#   script: "\nset -o pipefail \nset -o errexit\n\n#This defines the actual bed_prefix,\
#     \ assuming localisation of the input bed/bim/fam files\n\necho \"${bedfile}\"\n\
#     echo \"${bimfile}\"\necho \"${famfile}\"\n\nbed_prefix=/mnt/data/input/gs/fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr\"\
#     ${chrom}\" \n\nregenie     --step 1     --bed \"${bed_prefix}\"     --phenoFile\
#     \ \"${pheno_file}\"     --phenoCol \"${pheno}\"     --covarFile \"${cov_file}\"\
#     \     --catCovarList \"sex\"     --covarColList \"ht, wt, pc1, pc2, pc3, pc4,\
#     \ pc5, pc6, pc7, pc8, pc9, pc10, age_${pheno}\"     --bsize 1000     --extract\
#     \ \"${step1_snplist}\"     --verbose     --\"${trait}\"     --apply-rint     --ref-first\
#     \     --out \"${pheno}\"_step1_chr\"${chrom}\"\n\n#regenie pt 2\nregenie     --step\
#     \ 2     --bed \"${bed_prefix}\"     --phenoFile \"${pheno_file}\"     --phenoCol\
#     \ \"${pheno}\"     --covarFile \"${cov_file}\"     --catCovarList \"sex\"    \
#     \ --covarColList \"ht, wt, pc1, pc2, pc3, pc4, pc5, pc6, pc7, pc8, pc9, pc10,\
#     \ age_${pheno}\"     --pred \"${pheno}\"_step1_chr\"${chrom}\"_pred.list     --bsize\
#     \ 1000     --verbose     --\"${trait}\"     --apply-rint     --ref-first     --out\
#     \ \"${pheno}\"_step2_chr\"${chrom}\"\n\nexport regenie_results=\"${pheno}\"step2_chr\"\
#     {chrom}\".regenie\nmv ${regenie_results} -t ${OUTPUT_PATH}\n"
#   script-name: 2_regenie_aous_pp.sh
#   start-time: '2024-10-21 13:53:05.894116'
#   status: FAILURE
#   status-detail: 'Stopped running "user-command": exit status 1'
#   status-message: 'Stopped running "user-command": exit status 1'
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8
# - create-time: '2024-10-20 21:53:19.766357'
#   dsub-version: v0-5-0
#   end-time: '2024-10-20 22:17:06.120966'
#   envs:
#     GOOGLE_PROJECT: terra-vpc-sc-4e1b6fe8
#     chrom: '21'
#     pheno: NTproBNP
#     trait: qt
#   events:
#   - name: start
#     start-time: 2024-10-20 21:53:30.856279+00:00
#   - name: pulling-image
#     start-time: 2024-10-20 21:54:17.411703+00:00
#   - name: localizing-files
#     start-time: 2024-10-20 21:54:43.666837+00:00
#   - name: running-docker
#     start-time: 2024-10-20 22:16:54.631791+00:00
#   - name: fail
#     start-time: 2024-10-20 22:17:03.593331+00:00
#   - name: 'Execution failed: generic::failed_precondition: while running "user-command":
#       unexpected exit status 1 was not ignored'
#     start-time: 2024-10-20 22:17:05.769718+00:00
#   input-recursives: {}
#   inputs:
#     bedfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bed
#     bimfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.bim
#     cov_file: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_cov.tsv
#     famfile: gs://fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr21.fam
#     pheno_file: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_pheno.tsv
#     step1_snplist: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/1_regenie_plinkprep/jon126/results/21/qc_ldpruned_snps_chr21.prune.in
#   internal-id: projects/282373700333/locations/us-central1/operations/16966743372089952561
#   job-id: regenie-nt--jon126--241020-215319-62
#   job-name: regenie-ntprobnp
#   labels: {}
#   last-update: '2024-10-20 22:17:06.120966'
#   logging: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/regenie-ntprobnp/jon126/20241020/215318/regenie-nt--jon126--241020-215319-62-task-None.log
#   mounts: {}
#   output-recursives:
#     OUTPUT_PATH: gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/results/REGENIE_ntprobnp/jon126/20241020/results/21
#   outputs: {}
#   provider: google-cls-v2
#   provider-attributes:
#     accelerators: []
#     block-external-network: null
#     boot-disk-size: 100
#     cpu_platform: ''
#     disk-size: 1000
#     disk-type: pd-standard
#     enable-stackdriver-monitoring: false
#     instance-name: google-pipelines-worker-e001a7b7e9d7a80f55b21d0adfd58800
#     machine-type: n2-standard-4
#     network: network
#     preemptible: true
#     regions:
#     - us-central1
#     service-account: pet-27260071228379aa3ff1b@terra-vpc-sc-4e1b6fe8.iam.gserviceaccount.com
#     ssh: false
#     subnetwork: subnetwork
#     use_private_address: false
#     volumes: []
#     zone: us-central1-f
#     zones: []
#   script: "\nset -o pipefail \nset -o errexit\n\n#This defines the actual bed_prefix,\
#     \ assuming localisation of the input bed/bim/fam files\n\necho \"${bedfile}\"\n\
#     echo \"${bimfile}\"\necho \"${famfile}\"\n\nbed_prefix=/mnt/data/input/gs/fc-aou-datasets-controlled/v7/wgs/short_read/snpindel/acaf_threshold_v7.1/plink_bed/acaf_threshold.chr\"\
#     ${chrom}\" \n\nregenie     --step 1     --bed \"${bed_prefix}\"     --phenoFile\
#     \ \"${pheno_file}\"     --phenoCol \"${pheno}\"     --covarFile \"${cov_file}\"\
#     \     --catCovarList \"sex\"     --covarColList \"ht, wt, pc1, pc2, pc3, pc4,\
#     \ pc5, pc6, pc7, pc8, pc9, pc10, age_${pheno}\"     --bsize 1000     --extract\
#     \ \"${step1_snplist}\"     --verbose     --\"${trait}\"     --apply-rint     --ref-first\
#     \     --out \"${pheno}\"_step1_chr\"${chrom}\"\n\n#regenie pt 2\nregenie     --step\
#     \ 2     --bed \"${bed_prefix}\"     --phenoFile \"${pheno_file}\"     --phenoCol\
#     \ \"${pheno}\"     --covarFile \"${cov_file}\"     --catCovarList \"sex\"    \
#     \ --covarColList \"ht, wt, pc1, pc2, pc3, pc4, pc5, pc6, pc7, pc8, pc9, pc10,\
#     \ age_${pheno}\"     --pred \"${pheno}\"_step1_chr\"${chrom}\"_pred.list     --bsize\
#     \ 1000     --verbose     --\"${trait}\"     --apply-rint     --ref-first     --out\
#     \ \"${pheno}\"_step2_chr\"${chrom}\"\n\nexport regenie_results=\"${pheno}\"step2_chr\"\
#     {chrom}\".regenie\nmv ${regenie_results} -t ${OUTPUT_PATH}\n"
#   script-name: 2_regenie_aous_pp.sh
#   start-time: '2024-10-20 21:53:30.856279'
#   status: FAILURE
#   status-detail: 'Stopped running "user-command": exit status 1'
#   status-message: 'Stopped running "user-command": exit status 1'
#   user-id: jon126
#   user-project: terra-vpc-sc-4e1b6fe8

# %%
# !gsutil cp gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/regenie-ntprobnp/jon126/20241021/172243/regenie-nt--jon126--241021-172244-27-task-None.log ./
    
# !gsutil cp gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/PP/DATA/pp_regenie_pheno.tsv ./
# Out:
# Copying gs://fc-secure-7953e92c-a6a6-42df-9f19-86d553a9044f/dsub/logs/regenie-ntprobnp/jon126/20241021/172243/regenie-nt--jon126--241021-172244-27-task-None.log...
# / [1 files][ 13.8 KiB/ 13.8 KiB]
# Operation completed over 1 objects/13.8 KiB.

# %%
# !ddel --provider google-cls-v2 --project terra-vpc-sc-4e1b6fe8 --jobs '*' --users 'jon126' --location us-central1
# Out:
# Delete running jobs:
#   user:
#     {'jon126'}
#
#   job-id:
#     ['*']
#
# Found 1 tasks to delete.
# 1 job deleted
